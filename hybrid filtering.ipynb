# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Content-Based Filtering
def content_based_filtering(df, keywords):
    # Concatenate the selected columns into a single text column
    selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
    df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
    
    # Initialize TfidfVectorizer
    tfidf_vectorizer = TfidfVectorizer()
    
    # Fit and transform the text data
    tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])
    
    # Transform user input into a document
    user_document = ' '.join(keywords)
    user_vector = tfidf_vectorizer.transform([user_document])
    
    # Calculate cosine similarity between user input and house data
    cos_sim = cosine_similarity(user_vector, tfidf_matrix)
    
    # Get indices of houses sorted by relevance
    sorted_indices = cos_sim.argsort()[0][::-1]
    
    # Return top 5 most relevant houses
    top_recommendations = []
    for i in range(5):
        house_index = sorted_indices[i]
        relevance_score = cos_sim[0][house_index]
        recommendation = {
            'Category': df.iloc[house_index]['attributes.category_name'],
            'Subject': df.iloc[house_index]['attributes.subject'],
            'Body': df.iloc[house_index]['attributes.body'],
            'Region': df.iloc[house_index]['attributes.region_name'],
            'Property Type': df.iloc[house_index]['attributes.property_type_name'],
            'Relevance Score': relevance_score
        }
        top_recommendations.append(recommendation)
    return top_recommendations

# Collaborative Filtering
def collaborative_filtering(data, state):
    # Create User-Item Matrix
    user_item_matrix = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    
    # Initialize and fit NMF model
    num_components = 20  # Number of latent factors
    model = NMF(n_components=num_components, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    
    # Calculate RMSE
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    
    # Return reconstructed matrix and RMSE
    reconstructed_matrix = pd.DataFrame(np.round(X_reconstructed, 1), index=user_item_matrix.index, columns=user_item_matrix.columns)
    return reconstructed_matrix, rmse

# Hybrid Filtering
def hybrid_filtering(df, data, keywords, state):
    # Content-Based Filtering
    content_based_recommendations = content_based_filtering(df, keywords)
    
    # Collaborative Filtering
    reconstructed_matrix, rmse = collaborative_filtering(data, state)
    
    # Post-processing (e.g., combine recommendations, filter duplicates)
    # For simplicity, we'll just return both sets of recommendations
    return content_based_recommendations, reconstructed_matrix, rmse

# Load data
file_path_house = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
file_path_response = r"C:\Users\User\Desktop\response.csv"
df_house = pd.read_csv(file_path_house)
df_response = pd.read_csv(file_path_response)

# Get user input for keywords and state
keywords = input("Enter keywords to search for house: ").split()
state = input("Enter the state (Johor, Melaka, or Negeri Sembilan): ")

# Perform hybrid filtering
content_based_recommendations, reconstructed_matrix, rmse = hybrid_filtering(df_house, df_response, keywords, state)

# Display recommendations
print("\nContent-Based Recommendations:")
for i, recommendation in enumerate(content_based_recommendations, start=1):
    print(f"{i}. {recommendation}")

print("\nReconstructed Matrix:")
print(reconstructed_matrix)

print("\nRoot Mean Square Error (RMSE):", rmse)
# Out:
# Enter keywords to search for house: apartment
# Enter the state (Johor, Melaka, or Negeri Sembilan): melaka
#
# Content-Based Recommendations:
# 1. {'Category': 'apartment condominium', 'Subject': 'apartment sell', 'Body': 'selling furnished renovation price nego', 'Region': 'negeri sembilan', 'Property Type': 'apartment', 'Relevance Score': 0.7361519199382442}
# 2. {'Category': 'apartment condominium', 'Subject': 'apartment sale', 'Body': 'apartment sale cempaka court 3rd floor', 'Region': 'negeri sembilan', 'Property Type': 'apartment', 'Relevance Score': 0.7047959428563069}
# 3. {'Category': 'apartment condominium', 'Subject': 'ara ria apartment', 'Body': 'negotiable', 'Region': 'negeri sembilan', 'Property Type': 'apartment', 'Relevance Score': 0.6513482558543854}
# 4. {'Category': 'apartment condominium', 'Subject': 'apartment dahlia seremban', 'Body': 'apartment dahlia q sale 3rd floor non bumi lot bedroom ,1 bathroom ,1 toilet fully tile', 'Region': 'negeri sembilan', 'Property Type': 'apartment', 'Relevance Score': 0.5620001427552558}
# 5. {'Category': 'apartment condominium', 'Subject': 'villa krystall room apartment', 'Body': 'bumi lot call', 'Region': 'johor', 'Property Type': 'apartment', 'Relevance Score': 0.5525069291287363}
#
# Reconstructed Matrix:
#                              air_pollution\n  crime_rate  overall_rating  \
# Username
# Adilahatiqah24@gmail.com                 3.0         3.0             5.0
# aarongoh9912@gmail.com                   5.0         4.0             4.0
# ahmadtalin8@yahoo.com                    3.0         4.0             4.0
# aimanazfaryahaya@gmail.com               4.0         4.0             5.0
# athishan2122@gmail.com                   4.0         4.0             4.0
# chahuiyee33@gmail.com                    3.0         4.0             4.0
# chesterchin99@gmail.com                  3.0         3.0             3.0
# fatinfazil12@gmail.com                   5.0         4.0             4.0
# ganeshwaran44@gmail.com                  4.0         4.0             4.0
# izzaniabdul26@gmail.com                  3.0         3.0             4.0
# jasminleo123@gmail.com                   3.0         3.0             5.0
# jasvinnasingh90@gmail.com                3.0         4.0             4.0
# kohweehaw87@gmail.com                    3.0         4.0             5.0
# leowhui0505@gmail.com                    3.0         4.0             3.0
# limkeeksiang@yahoo.com                   4.0         3.0             4.0
# limzefeng349@gmail.com                   3.0         4.0             4.0
# moojiajie2000@gmail.com                  3.0         4.0             4.0
# nurazianbahri1998@gmail.com              3.0         4.0             4.0
# ruyi2510wong@gmail.com                   5.0         4.0             4.0
# sandychuah@gmail.com                     4.0         4.0             4.0
# selvinayagan332@yahoo.com                4.0         4.0             4.0
# syazriniemohdnoor@gmail.com              4.0         4.0             4.0
# vithralini90@yahoo.com                   5.0         5.0             3.0
# xinjie8596@gmail.com                     3.0         3.0             4.0
# xuetengng@gmail.com                      5.0         4.0             4.0
#
#                              sound_pollution  traffic\n
# Username
# Adilahatiqah24@gmail.com                 2.0        3.0
# aarongoh9912@gmail.com                   4.0        4.0
# ahmadtalin8@yahoo.com                    4.0        4.0
# aimanazfaryahaya@gmail.com               3.0        4.0
# athishan2122@gmail.com                   4.0        4.0
# chahuiyee33@gmail.com                    4.0        3.0
# chesterchin99@gmail.com                  3.0        4.0
# fatinfazil12@gmail.com                   5.0        5.0
# ganeshwaran44@gmail.com                  4.0        4.0
# izzaniabdul26@gmail.com                  4.0        4.0
# jasminleo123@gmail.com                   3.0        4.0
# jasvinnasingh90@gmail.com                3.0        4.0
# kohweehaw87@gmail.com                    3.0        4.0
# leowhui0505@gmail.com                    3.0        4.0
# limkeeksiang@yahoo.com                   4.0        3.0
# limzefeng349@gmail.com                   4.0        4.0
# moojiajie2000@gmail.com                  3.0        3.0
# nurazianbahri1998@gmail.com              5.0        4.0
# ruyi2510wong@gmail.com                   5.0        4.0
# sandychuah@gmail.com                     4.0        4.0
# selvinayagan332@yahoo.com                3.0        5.0
# syazriniemohdnoor@gmail.com              4.0        5.0
# vithralini90@yahoo.com                   5.0        4.0
# xinjie8596@gmail.com                     3.0        3.0
# xuetengng@gmail.com                      4.0        4.0
#
# Root Mean Square Error (RMSE): 7.992878224702552e-05

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Concatenate the selected columns into a single text column
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and trail data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of trails sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with RMSE
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse_melaka:.6f}")
# Out:
# Enter keywords to search for house: condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Calculate RMSE for Johor
rmse_johor = np.sqrt(np.mean((X_johor - X_reconstructed_johor)**2))

# Concatenate the selected columns into a single text column for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and trail data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of trails sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE Johor: {rmse_johor:.6f}, RMSE Melaka: {rmse_melaka:.6f}, RMSE Negeri Sembilan: {rmse_negeri_sembilan:.6f}")
# Out:
# Enter keywords to search for house: 3 bedrooms
# Combined Recommendations:
# 1. Category: house, Subject: taman desa bertam double storey sale, Body: taman desa bertam double storey sale bedrooms/bathrooms bed bath size x sqft ownership non bumi lot renovation detail basic unit renovation selling price rm 540k, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.24) RMSE Johor: 0.000080, RMSE Melaka: 0.000043, RMSE Negeri Sembilan: 0.000086
# 2. Category: house, Subject: 22x70sf double storey house sale tun aminah skudai full loan, Body: taman ungku tun aminah sale double storey bedrooms,3 bathroom land size 22x70sqft 1540sqft freehold non- bumi lot  call detail viewing appointment  alan lin , Region: johor, Property Type: 2-storey terraced house (Relevance Score: 0.21) RMSE Johor: 0.000080, RMSE Melaka: 0.000043, RMSE Negeri Sembilan: 0.000086
# 3. Category: house, Subject: seri alam jalan lembah 2.5 storey house sale, Body: sale jalan lembah seri alam 2.5 storey terrace house land area 1,870 sqft bedrooms,4 bathroom freehold international lot gated guarded maintenance fee rm selling price rm 680k, Region: johor, Property Type: 2.5-storey terraced house (Relevance Score: 0.21) RMSE Johor: 0.000080, RMSE Melaka: 0.000043, RMSE Negeri Sembilan: 0.000086
# 4. Category: house, Subject: storey terrace taman merdeka jaya, Body: sale storey terrace taman merdeka jaya price rm388,000 tenure leasehold land area 20'x70' bedrooms-4 bathrooms-3 renovated refurbished fully tile plaster ceiling upstairs floor spc detail kindly contact jason 011-1090 thank, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.20) RMSE Johor: 0.000080, RMSE Melaka: 0.000043, RMSE Negeri Sembilan: 0.000086
# 5. Category: house, Subject: seri alam 2.5 storey terrace bedroom renovated g g good condition, Body: seri alam 2.5  for sale jalan lembah seri alam  2.5 storey terrace house  land area 1,870 sqft  bedrooms,4 bathroom  freehold  international lot  gated guarded  maintenance fee rm selling pricerm680k, Region: johor, Property Type: 2.5-storey terraced house (Relevance Score: 0.20) RMSE Johor: 0.000080, RMSE Melaka: 0.000043, RMSE Negeri Sembilan: 0.000086

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and trail data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of trails sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter keywords to search for house: 3 bedrooms
# Combined Recommendations:
# 1. Category: house, Subject: taman desa bertam double storey sale, Body: taman desa bertam double storey sale bedrooms/bathrooms bed bath size x sqft ownership non bumi lot renovation detail basic unit renovation selling price rm 540k, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.24) RMSE: 0.000043
# 2. Category: house, Subject: 22x70sf double storey house sale tun aminah skudai full loan, Body: taman ungku tun aminah sale double storey bedrooms,3 bathroom land size 22x70sqft 1540sqft freehold non- bumi lot  call detail viewing appointment  alan lin , Region: johor, Property Type: 2-storey terraced house (Relevance Score: 0.21) RMSE: 0.000080
# 3. Category: house, Subject: seri alam jalan lembah 2.5 storey house sale, Body: sale jalan lembah seri alam 2.5 storey terrace house land area 1,870 sqft bedrooms,4 bathroom freehold international lot gated guarded maintenance fee rm selling price rm 680k, Region: johor, Property Type: 2.5-storey terraced house (Relevance Score: 0.21) RMSE: 0.000080
# 4. Category: house, Subject: storey terrace taman merdeka jaya, Body: sale storey terrace taman merdeka jaya price rm388,000 tenure leasehold land area 20'x70' bedrooms-4 bathrooms-3 renovated refurbished fully tile plaster ceiling upstairs floor spc detail kindly contact jason 011-1090 thank, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.20) RMSE: 0.000043
# 5. Category: house, Subject: seri alam 2.5 storey terrace bedroom renovated g g good condition, Body: seri alam 2.5  for sale jalan lembah seri alam  2.5 storey terrace house  land area 1,870 sqft  bedrooms,4 bathroom  freehold  international lot  gated guarded  maintenance fee rm selling pricerm680k, Region: johor, Property Type: 2.5-storey terraced house (Relevance Score: 0.20) RMSE: 0.000080

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]


# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  10000
# Enter keywords to search for house:  terrace
# Combined Recommendations:
# 1. Category: house, Subject: bukit baru storey terrace, Body: freehold, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.31) RMSE: 0.000043
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 110
#     108 relevance_score = cos_sim[0][house_index]
#     109 if house_region.lower() == 'johor':
# --> 110     rmse = rmse_johor
#     111 elif house_region.lower() == 'melaka':
#     112     rmse = rmse_melaka
#
# NameError: name 'rmse_johor' is not defined

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]


# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  1000
# Enter keywords to search for house:  terrace
# Combined Recommendations:
# 1. Category: house, Subject: bukit baru storey terrace, Body: freehold, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.31) RMSE: 0.000043
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 110
#     108 relevance_score = cos_sim[0][house_index]
#     109 if house_region.lower() == 'johor':
# --> 110     rmse = rmse_johor
#     111 elif house_region.lower() == 'melaka':
#     112     rmse = rmse_melaka
#
# NameError: name 'rmse_johor' is not defined

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Initialize default RMSE values
rmse_johor = 0.0
rmse_melaka = 0.0
rmse_negeri_sembilan = 0.0

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  10000
# Enter keywords to search for house:  terrace
# Combined Recommendations:
# 1. Category: house, Subject: bukit baru storey terrace, Body: freehold, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.31) RMSE: 0.000000
# 2. Category: house, Subject: kota masai single storey terrace terrace full loan, Body: single storey terrace house jalan bacang kota masai intermediate lot free hold 20x70 non bumi facing road bedroom bathroom selling price rm330k  alvin ng, Region: johor, Property Type: 1-storey terraced house (Relevance Score: 0.29) RMSE: 0.000000
# 3. Category: house, Subject: double story terrace freehold non bumi lot, Body: double storey terrace house beliza tiara sendayan property detail double storey terrace intermediate 2071sqft bedroom bathroom non bumi lot freehold brand new unit full loan asking price 410k, Region: negeri sembilan, Property Type: 2-storey terraced house (Relevance Score: 0.28) RMSE: 0.000000
# 4. Category: house, Subject: bukit beruang freehold storey terrace taman kerjasama, Body: bukit beruang single storey terrace -- sale rm 350,000 -- single storey terrace size x sq.ft bed bath toilet facing south chinese area detail/viewing please call wong ren contact 016-6568218, Region: melaka, Property Type: 1-storey terraced house (Relevance Score: 0.26) RMSE: 0.000000
# 5. Category: house, Subject: bukit baru double storey terrace corner house sale, Body: bukit baru double storey terrace corner lot sale behind manipal college type property double storey terrace corner lot freehold non bumi title bedroom bathroom land area sqft build x kitchen fully extended new floor tile house condition good refurbished contact wesley +6017-6889998, Region: melaka, Property Type: 2-storey terraced house (Relevance Score: 0.23) RMSE: 0.000000

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Negeri Sembilan
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  1000
# Enter keywords to search for house:  condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  10000
# Enter keywords to search for house:  condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Calculate RMSE for Johor
rmse_johor = np.sqrt(np.mean((X_johor - X_reconstructed_johor)**2))

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  10000
# Enter keywords to search for house:  condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Calculate RMSE for Johor
rmse_johor = np.sqrt(np.mean((X_johor - X_reconstructed_johor)**2))

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  1000
# Enter keywords to search for house:  condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Calculate RMSE for Johor
rmse_johor = np.sqrt(np.mean((X_johor - X_reconstructed_johor)**2))

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ")
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  10000
# Enter keywords to search for house:  condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Calculate RMSE for Johor
rmse_johor = np.sqrt(np.mean((X_johor - X_reconstructed_johor)**2))

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Prompt the user to input preferences
location = input("Enter your preferred location (Johor, Melaka, or Negeri Sembilan): ").lower()
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Enter your preferred location (Johor, Melaka, or Negeri Sembilan):  Johor
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  1000
# Enter keywords to search for house:  condo
# Combined Recommendations:
# 1. Category: apartment condominium, Subject: cash back rm90k super value casa lago condo melaka raya, Body: rm208k introduction strategic location land area sqft bedroom bathroom leasehold non bumi lot nearby atlantis residence condo admiral residence condo wave residence condo ocean palm condo, Region: melaka, Property Type: condominium (Relevance Score: 0.64) RMSE: 0.000043
# 2. Category: apartment condominium, Subject: fully furnish room freehold condo bachang kampung lapan melaka, Body: best stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo kenanga residence condo admiral residence condo sri melaka residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.62) RMSE: 0.000043
# 3. Category: apartment condominium, Subject: room condo sale, Body: 1room condo sale tanjong kling melaka price 110k negotiable detail contact tan, Region: melaka, Property Type: studio (Relevance Score: 0.46) RMSE: 0.000043
# 4. Category: apartment condominium, Subject: freehold room condominium near aeon bandaraya melaka, Body: good stay long term investment introduction strategic location land area sq.ft bedroom bathroom fully furnish non bumi lot freehold nearby atlantis residence condo wave residence condo admiral residence condo sell lease contact z service derrickyeeproperty, Region: melaka, Property Type: service residence (Relevance Score: 0.44) RMSE: 0.000043
# 5. Category: apartment condominium, Subject: casuarina park pandan wangi condominium limbongan melaka, Body: condominium casuarina park untuk dijual .. fully furnished .. condo near oriental hospital pantai klebang restoran sekolah tengkera melaka international school planetarium international school minit car bandar hilir melaka condo ini muslim owner facility condo floor swimming pool tennis court 24/7 security gym berminat boleh datang tengok dan boleh contact saya sepupu owner penjagaan condo, Region: melaka, Property Type: condominium (Relevance Score: 0.42) RMSE: 0.000043

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)


# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print user input keywords for debugging
print("User Input Keywords:", keywords)

# Extract region name from DataFrame
house_region = df.iloc[house_index]['attributes.region_name']

# Print region name extracted from DataFrame for debugging
print("Region Extracted from DataFrame:", house_region)

# Print DataFrame rows containing 'melaka'
print("Rows with 'negeri sembilan' region:")
print(df[df['attributes.region_name'] == 'negeri sembilan'])

# Print DataFrame rows containing 'melaka'
print("Rows with 'melaka' region:")
print(df[df['attributes.region_name'] == 'melaka'])

# Print DataFrame rows containing 'johor'
print("Rows with 'johor' region:")
print(df[df['attributes.region_name'] == 'johor'])

# Extract region name from DataFrame
house_region = df.iloc[house_index]['attributes.region_name']


# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    
    # Add the print statement to check the value of house_region
    print("House Region:", house_region)
    
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
        
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Unique Regions: ['johor' 'melaka' 'negeri sembilan']
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  12312
# Enter keywords to search for house:  flat negeri sembilan
# User Input Keywords: ['flat', 'negeri', 'sembilan']
# Region Extracted from DataFrame: johor
# Rows with 'negeri sembilan' region:
#       attributes.category_name  \
# 15656                    house
# 15657                    house
# 15658                    house
# 15659                    house
# 15660                    house
# ...                        ...
# 25248                    house
# 25249                    house
# 25250                    house
# 25251                    house
# 25252                    house
#
#                                       attributes.subject  \
# 15656  banglo tingkat fasa 1d sq ft taman juasseh sen...
# 15657  taman juasseh sentosa banglo tingkat sq ft fas...
# 15658  fasa 1d banglo tingkat sq ft taman juasseh sen...
# 15659  banglo tingkat sq ft fasa 1d taman juasseh sen...
# 15660        open facing| nice view bandar seri sendayan
# ...                                                  ...
# 25248                          fully renovated safe area
# 25249                   tmn bkt mutiara temiang seremban
# 25250   double storey house suriaman bandar sri sendayan
# 25251  rumah untuk dilepaskan kawasan springhill port...
# 25252    sale hill top ara sendayan cadena double storey
#
#       attributes.bathroom_name attributes.rooms_name  \
# 15656                        2                     4
# 15657                        2                     4
# 15658                        2                     4
# 15659                        2                     4
# 15660                        4                     4
# ...                        ...                   ...
# 25248                        2                     2
# 25249                        2                     3
# 25250                        4                     5
# 25251                        2                     3
# 25252                        4                     4
#
#                                          attributes.body  attributes.price  \
# 15656  banglo tingkat sq ft fasa 1d taman juasseh sen...            520100
# 15657  banglo tingkat sq ft fasa 1d taman juasseh sen...            520100
# 15658  banglo tingkat sq ft fasa 1d taman juasseh sen...            520100
# 15659  banglo tingkat sq ft fasa 1d taman juasseh sen...            520100
# 15660  sale open facing nice view double storey terra...            700000
# ...                                                  ...               ...
# 25248  shop.hospital.market school.speed mart99 uitm ...            280000
# 25249  minit utk ke bdr seremban jalan lekas utk ke c...            220000
# 25250  urgent sale corner unit freehold double storey...            685000
# 25251  aminities ucsi hospital ucsi international sch...            230000
# 25252  asking price rm 680k negotiable detail freehol...            680000
#
#       attributes.region_name attributes.property_type_name  attributes.size  \
# 15656        negeri sembilan                bungalow house           5899.0
# 15657        negeri sembilan                bungalow house           5899.0
# 15658        negeri sembilan                bungalow house           5899.0
# 15659        negeri sembilan                bungalow house           5899.0
# 15660        negeri sembilan       2-storey terraced house           2200.0
# ...                      ...                           ...              ...
# 25248        negeri sembilan       2-storey terraced house             78.0
# 25249        negeri sembilan       1-storey terraced house           1400.0
# 25250        negeri sembilan       2-storey terraced house           2840.0
# 25251        negeri sembilan       2-storey terraced house            800.0
# 25252        negeri sembilan       2-storey terraced house           2584.0
#
#       attributes.price_label            links.image_baseurl  \
# 15656                520,100  https://img.rnudah.com/images
# 15657                520,100  https://img.rnudah.com/images
# 15658                520,100  https://img.rnudah.com/images
# 15659                520,100  https://img.rnudah.com/images
# 15660                700,000  https://img.rnudah.com/images
# ...                      ...                            ...
# 25248                280,000  https://img.rnudah.com/images
# 25249                220,000  https://img.rnudah.com/images
# 25250                685,000  https://img.rnudah.com/images
# 25251                230,000  https://img.rnudah.com/images
# 25252                680,000  https://img.rnudah.com/images
#
#                                                     text
# 15656  house banglo tingkat fasa 1d sq ft taman juass...
# 15657  house taman juasseh sentosa banglo tingkat sq ...
# 15658  house fasa 1d banglo tingkat sq ft taman juass...
# 15659  house banglo tingkat sq ft fasa 1d taman juass...
# 15660  house open facing| nice view bandar seri senda...
# ...                                                  ...
# 25248  house fully renovated safe area shop.hospital....
# 25249  house tmn bkt mutiara temiang seremban minit u...
# 25250  house double storey house suriaman bandar sri ...
# 25251  house rumah untuk dilepaskan kawasan springhil...
# 25252  house sale hill top ara sendayan cadena double...
#
# [9597 rows x 12 columns]
# Rows with 'melaka' region:
#       attributes.category_name  \
# 9993                     house
# 9994                     house
# 9995                     house
# 9996                     house
# 9997                     house
# ...                        ...
# 15651                    house
# 15652    apartment condominium
# 15653    apartment condominium
# 15654    apartment condominium
# 15655    apartment condominium
#
#                                       attributes.subject  \
# 9993   gated guarded security freehold storey terrace...
# 9994   freehold club house pool huge double storey se...
# 9995   zero booking freehold extra land bumi sty semi...
# 9996   extra foot land single storey semi jasin mydin...
# 9997   full loan freehold storey house jasin bandar b...
# ...                                                  ...
# 15651  semi detached single story mcl taman rambai te...
# 15652  furnished studio unit condo savoy famosa resor...
# 15653                              banda hilir flat sale
# 15654                                imperio studio sale
# 15655                               malim jaya flat sale
#
#       attributes.bathroom_name attributes.rooms_name  \
# 9993                         4                     4
# 9994                         4                     4
# 9995                         2                     4
# 9996                         2                     4
# 9997                         3                     4
# ...                        ...                   ...
# 15651                        2                     4
# 15652                        1                     2
# 15653                        1                     2
# 15654                        1                     1
# 15655                        1                     3
#
#                                          attributes.body  attributes.price  \
# 9993   selling price rm650,000 property detail -freeh...            650000
# 9994   selling price rm850,000 property detail -freeh...            850000
# 9995   selling price rm453,000 house introduction bum...            453000
# 9996   selling price rm432,000 property detail -freeh...            432000
# 9997   selling price rm433,000 property detail freeho...            433000
# ...                                                  ...               ...
# 15651  freehold mcl partially furnished 40ft x 80ft q...            470000
# 15652  condo terletak di famosa resort dan berhampi d...            165000
# 15653  banda hilir flat sale view please contact 014-...             78000
# 15654                             please contact viewing            358000
# 15655  hi im selling flat rm80k highly nego flat curr...             80000
#
#       attributes.region_name attributes.property_type_name  attributes.size  \
# 9993                  melaka       2-storey terraced house           1760.0
# 9994                  melaka           semi-detached house           3200.0
# 9995                  melaka           semi-detached house           2450.0
# 9996                  melaka           semi-detached house           2700.0
# 9997                  melaka       2-storey terraced house           1680.0
# ...                      ...                           ...              ...
# 15651                 melaka           semi-detached house           3200.0
# 15652                 melaka                   condominium            805.0
# 15653                 melaka                          flat            720.0
# 15654                 melaka             service residence            430.0
# 15655                 melaka                     apartment            850.0
#
#       attributes.price_label            links.image_baseurl  \
# 9993                 650,000  https://img.rnudah.com/images
# 9994                 850,000  https://img.rnudah.com/images
# 9995                 453,000  https://img.rnudah.com/images
# 9996                 432,000  https://img.rnudah.com/images
# 9997                 433,000  https://img.rnudah.com/images
# ...                      ...                            ...
# 15651                470,000  https://img.rnudah.com/images
# 15652                165,000  https://img.rnudah.com/images
# 15653                 78,000  https://img.rnudah.com/images
# 15654                358,000  https://img.rnudah.com/images
# 15655                 80,000  https://img.rnudah.com/images
#
#                                                     text
# 9993   house gated guarded security freehold storey t...
# 9994   house freehold club house pool huge double sto...
# 9995   house zero booking freehold extra land bumi st...
# 9996   house extra foot land single storey semi jasin...
# 9997   house full loan freehold storey house jasin ba...
# ...                                                  ...
# 15651  house semi detached single story mcl taman ram...
# 15652  apartment condominium furnished studio unit co...
# 15653  apartment condominium banda hilir flat sale ba...
# 15654  apartment condominium imperio studio sale plea...
# 15655  apartment condominium malim jaya flat sale hi ...
#
# [5663 rows x 12 columns]
# Rows with 'johor' region:
#      attributes.category_name  \
# 0       apartment condominium
# 1                       house
# 2                       house
# 3       apartment condominium
# 4                       house
# ...                       ...
# 9988                    house
# 9989                    house
# 9990                    house
# 9991                    house
# 9992                    house
#
#                                      attributes.subject  \
# 0     twin danga residende perling min jb town ciq m...
# 1     2sty taman kulai baru full loan+cash back new ...
# 2     taman sri kulai baru storey full loan+cash bac...
# 3     ehsan jaya shop apartment bumi lot tingkatsatu...
# 4     pasir gudang masai double storey house good co...
# ...                                                 ...
# 9988  corner lot  besar dah siap renovate jalan duku...
# 9989  full renovation  tampoi utama jalan sri perkas...
# 9990  mutiara ma mutiara rini storey cluster brand n...
# 9991     single storey terrace/taman sri pulai/for sale
# 9992  senai utama single storey terrace renovated go...
#
#      attributes.bathroom_name attributes.rooms_name  \
# 0                           2                     2
# 1                           2                     4
# 2                           2                     4
# 3                           2                     3
# 4                           2                     3
# ...                       ...                   ...
# 9988                        2                     4
# 9989                        3                     4
# 9990                        4                     5
# 9991                        2                     3
# 9992                        2                     3
#
#                                         attributes.body  attributes.price  \
# 0     sale  k market rate twin danga residence taman...            358000
# 1     sale taman sri kulai baru batu jalan bunga ro ...            468000
# 2     taman sri kulai baru batu jalan bunga ro  save...            468500
# 3     harga rumahrm182k  ansuran bulanan rm950+- jal...            182000
# 4     harga rumahrm365k  ansuran bulanan rm1800+- ca...            365000
# ...                                                 ...               ...
# 9988  jalan duku tmn kota masai pasir gudang double ...            409000
# 9989  jalan sri perkasa xx taman tampoi utama johor ...            530000
# 9990  sale taman mutiara ma jalan mutiara 4/x jade s...           1100000
# 9991  sale jalan meranti taman sri pulai johor bahru...            390000
# 9992  sale single storey renovation unit taman senai...            415000
#
#      attributes.region_name attributes.property_type_name  attributes.size  \
# 0                     johor             service residence            749.0
# 1                     johor       2-storey terraced house           1540.0
# 2                     johor       2-storey terraced house           1540.0
# 3                     johor                     apartment            750.0
# 4                     johor       2-storey terraced house            960.0
# ...                     ...                           ...              ...
# 9988                  johor       2-storey terraced house           2639.0
# 9989                  johor       2-storey terraced house           1539.0
# 9990                  johor       3-storey terraced house           3948.0
# 9991                  johor       1-storey terraced house           1540.0
# 9992                  johor       1-storey terraced house           1540.0
#
#      attributes.price_label            links.image_baseurl  \
# 0                   358,000  https://img.rnudah.com/images
# 1                   468,000  https://img.rnudah.com/images
# 2                   468,500  https://img.rnudah.com/images
# 3                   182,000  https://img.rnudah.com/images
# 4                   365,000  https://img.rnudah.com/images
# ...                     ...                            ...
# 9988                409,000  https://img.rnudah.com/images
# 9989                530,000  https://img.rnudah.com/images
# 9990              1,100,000  https://img.rnudah.com/images
# 9991                390,000  https://img.rnudah.com/images
# 9992                415,000  https://img.rnudah.com/images
#
#                                                    text
# 0     apartment condominium twin danga residende per...
# 1     house 2sty taman kulai baru full loan+cash bac...
# 2     house taman sri kulai baru storey full loan+ca...
# 3     apartment condominium ehsan jaya shop apartmen...
# 4     house pasir gudang masai double storey house g...
# ...                                                 ...
# 9988  house corner lot  besar dah siap renovate jala...
# 9989  house full renovation  tampoi utama jalan sri ...
# 9990  house mutiara ma mutiara rini storey cluster b...
# 9991  house single storey terrace/taman sri pulai/fo...
# 9992  house senai utama single storey terrace renova...
#
# [9993 rows x 12 columns]
# Combined Recommendations:
# House Region: johor
# 1. Category: apartment condominium, Subject: flat austin perdana, Body: high floor, Region: johor, Property Type: flat (Relevance Score: 0.57) RMSE: 0.000080
# House Region: johor
# 2. Category: apartment condominium, Subject: tun aminah low cost flat sale, Body: sale tun aminah flat blok flat low cost flat third floor bedroom bathroom 494sqft freehold basic renovated selling price rm150k, Region: johor, Property Type: flat (Relevance Score: 0.54) RMSE: 0.000080
# House Region: johor
# 3. Category: apartment condominium, Subject: flat sale, Body: sale flat camar perling  level  r b  sq ft  non-bumi  freehold  balcony  fully tile  table top  cabinet harga rm160k , Region: johor, Property Type: flat (Relevance Score: 0.52) RMSE: 0.000080
# House Region: negeri sembilan
# 4. Category: apartment condominium, Subject: flat bilik untuk dijual, Body: flat seri rasah bilik untuk dijual 59k berdekatan uitm s3 contact, Region: negeri sembilan, Property Type: flat (Relevance Score: 0.52) RMSE: 0.000086
# House Region: johor
# 5. Category: apartment condominium, Subject: skudai flat taman ungku tun aminah sale, Body: sale flat tun aminah low cost flat highest floor build sqft bedroom bathroom freehold non bumi selling price rm135k nego, Region: johor, Property Type: flat (Relevance Score: 0.50) RMSE: 0.000080

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)


# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print user input keywords for debugging
print("User Input Keywords:", keywords)

# Initialize a variable to store the house region
house_region = None

# Iterate through the sorted indices to find the first house with a matching region
for index in sorted_indices:
    current_region = df.iloc[index]['attributes.region_name']
    if current_region.lower() in unique_regions:
        house_region = current_region
        break

# Check if a matching region was found
if house_region:
    print("Region Extracted from DataFrame:", house_region)
else:
    print("No matching region found for the selected houses.")

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    
    # Extract region name from DataFrame
    house_region = df.iloc[house_index]['attributes.region_name']
    
    # Add the print statement to check the value of house_region
    print("House Region:", house_region)
    
    if house_region.lower() == 'johor':
        rmse = rmse_johor
    elif house_region.lower() == 'melaka':
        rmse = rmse_melaka
    elif house_region.lower() == 'negeri sembilan':
        rmse = rmse_negeri_sembilan
        
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
# Out:
# Unique Regions: ['johor' 'melaka' 'negeri sembilan']
# Enter your preferred number of bedroom:  2
# Enter your preferred price range(RM):  123123
# Enter keywords to search for house:  flat melaka
# User Input Keywords: ['flat', 'melaka']
# Region Extracted from DataFrame: johor
# Combined Recommendations:
# House Region: johor
# 1. Category: apartment condominium, Subject: flat austin perdana, Body: high floor, Region: johor, Property Type: flat (Relevance Score: 0.59) RMSE: 0.000080
# House Region: melaka
# 2. Category: apartment condominium, Subject: cheng ria flat sale, Body: near shop easy access highway good environment, Region: melaka, Property Type: flat (Relevance Score: 0.57) RMSE: 0.000043
# House Region: johor
# 3. Category: apartment condominium, Subject: tun aminah low cost flat sale, Body: sale tun aminah flat blok flat low cost flat third floor bedroom bathroom 494sqft freehold basic renovated selling price rm150k, Region: johor, Property Type: flat (Relevance Score: 0.56) RMSE: 0.000080
# House Region: johor
# 4. Category: apartment condominium, Subject: flat sale, Body: sale flat camar perling  level  r b  sq ft  non-bumi  freehold  balcony  fully tile  table top  cabinet harga rm160k , Region: johor, Property Type: flat (Relevance Score: 0.53) RMSE: 0.000080
# House Region: johor
# 5. Category: apartment condominium, Subject: skudai flat taman ungku tun aminah sale, Body: sale flat tun aminah low cost flat highest floor build sqft bedroom bathroom freehold non bumi selling price rm135k nego, Region: johor, Property Type: flat (Relevance Score: 0.52) RMSE: 0.000080

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)


# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print user input keywords for debugging
print("User Input Keywords:", keywords)

# Initialize a list to store the house regions
house_regions = []

# Iterate through the sorted indices to find the region for each house
for index in sorted_indices:
    current_region = df.iloc[index]['attributes.region_name']
    if current_region.lower() in unique_regions:
        house_regions.append(current_region)
    else:
        house_regions.append(None)

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    
    # Extract region name from the list of house regions
    house_region = house_regions[i]
    
    if house_region:
        if house_region.lower() == 'johor':
            rmse = rmse_johor
        elif house_region.lower() == 'melaka':
            rmse = rmse_melaka
        elif house_region.lower() == 'negeri sembilan':
            rmse = rmse_negeri_sembilan
        
        print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f}) RMSE: {rmse:.6f}")
    else:
        print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: No matching region found, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f})")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 14
#       8 data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")
#      10 # Preprocess the data if necessary
#      11 # For example, handle missing values or clean the data
#      12
#      13 # Create User-Item Matrix for Melaka
# ---> 14 user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')
#      16 # Fill missing values with 0 for Melaka
#      17 user_item_matrix_melaka.fillna(0, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'traffic\n.1'

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Create User-Item Matrix for Negeri Sembilan
user_item_matrix_negeri_sembilan = pd.pivot_table(data, values=['traffic\n.2', 'air_pollution\n.2', 'sound_pollution.2', 'crime_rate.2', 'overall_rating.2'], index='Username')

# Fill missing values with 0 for Negeri Sembilan
user_item_matrix_negeri_sembilan.fillna(0, inplace=True)

# Convert Negeri Sembilan user-item matrix to numpy array
X_negeri_sembilan = user_item_matrix_negeri_sembilan.values

# Initialize and fit NMF model for Negeri Sembilan
model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)
X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Calculate RMSE for Negeri Sembilan
rmse_negeri_sembilan = np.sqrt(np.mean((X_negeri_sembilan - X_reconstructed_negeri_sembilan)**2))

# Create User-Item Matrix for Johor
user_item_matrix_johor = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')

# Fill missing values with 0 for Johor
user_item_matrix_johor.fillna(0, inplace=True)

# Convert Johor user-item matrix to numpy array
X_johor = user_item_matrix_johor.values

# Initialize and fit NMF model for Johor
model_johor = NMF(n_components=num_components, init='random', random_state=20)
W_johor = model_johor.fit_transform(X_johor)  # Factorization of X_johor into W_johor and H_johor

# Reconstruction of X from the factorized matrices
X_reconstructed_johor = np.dot(W_johor, model_johor.components_)

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)

# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of properties sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Print user input keywords for debugging
print("User Input Keywords:", keywords)

# Print top 5 most relevant houses with combined results
print("Combined Recommendations:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    
    # Extract region name from DataFrame
    house_region = df.iloc[house_index]['attributes.region_name']
    
    # Check if the extracted region contains the user-input region
    if house_region.lower() in [region.lower() for region in unique_regions]:
        # Check which region the house belongs to and assign the corresponding RMSE
        if house_region.lower() == 'melaka':
            rmse = rmse_melaka
        elif house_region.lower() == 'negeri sembilan':
            rmse = rmse_negeri_sembilan
        elif house_region.lower() == 'johor':
            rmse = rmse_johor
        else:
            rmse = "N/A"  # If region not found, set RMSE as Not Available
        
        print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, RMSE: {rmse}")
    else:
        print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region} (Relevance Score: {relevance_score:.2f}")
# Out:
# Unique Regions: ['johor' 'melaka' 'negeri sembilan']
# Enter your preferred number of bedroom:
# Enter your preferred price range(RM):
# Enter keywords to search for house:  bungalow johor
# User Input Keywords: ['bungalow', 'johor']
# Combined Recommendations:
# 1. Category: house, Subject: bungalow banglo taman desa molek a++, Body: fully renovated bungalow beside river nice, Region: melaka, RMSE: 4.3213730497077075e-05
# 2. Category: house, Subject: freehold bungalow sale, Body:  house sale  krubong perdana  single storey bungalow  freehold  land size sqft  60x100 sqft  bedroom bathroom  facing southwest  fully renovated furnished, Region: melaka, RMSE: 4.3213730497077075e-05
# 3. Category: house, Subject: 1.5 storey bungalow seremban south taman senawang perdana seremban, Body: direct owner, Region: negeri sembilan, RMSE: 8.572222462193857e-05
# 4. Category: house, Subject: taman suria bungalow town jb johor double storey larkin sale, Body: sale taman suria johor double storey bungalow bedroom bathroom land size x built sqft facing southwest international lot freehold unblock view unit ~selling price rm 1.3 mil ~kindly contact m kimi 010-8859619, Region: johor, RMSE: 7.992878224698512e-05
# 5. Category: house, Subject: bungalow double storey, Body: residenmas taman permatang pasir perdana .free flood unit left bungalow, Region: melaka, RMSE: 4.3213730497077075e-05

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)

# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Get user input for keywords
keywords_input = input("Enter keywords to search for house: ")
keywords = keywords_input.split(',')

# Filter the dataset to include only properties from the specified region
if 'johor' in unique_regions and 'johor' in keywords_input.lower():
    df_region = df[df['attributes.region_name'].str.lower() == 'johor']
    X_region = X_melaka  # Using collaborative filtering data for Johor
elif 'melaka' in unique_regions and 'melaka' in keywords_input.lower():
    df_region = df[df['attributes.region_name'].str.lower() == 'melaka']
    X_region = X_melaka  # Using collaborative filtering data for Melaka
elif 'negeri sembilan' in unique_regions and 'negeri sembilan' in keywords_input.lower():
    df_region = df[df['attributes.region_name'].str.lower() == 'negeri sembilan']
    X_region = X_melaka  # Using collaborative filtering data for Negeri Sembilan
else:
    print("Region specified in the user input is not available in the dataset.")
    # You might want to handle this case differently based on your requirements
    exit()

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df_region['text'] = df_region[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix_region = tfidf_vectorizer.fit_transform(df_region['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data in the specified region
cos_sim_region = cosine_similarity(user_vector, tfidf_matrix_region)

# Get indices of properties in the specified region sorted by relevance
sorted_indices_region = cos_sim_region.argsort()[0][::-1]

# Print top 5 most relevant houses in the specified region
print("Content-Based Recommendations in the specified region:")
for i in range(5):
    house_index_region = sorted_indices_region[i]
    house_category_region = df_region.iloc[house_index_region]['attributes.category_name']
    house_subject_region = df_region.iloc[house_index_region]['attributes.subject']
    house_body_region = df_region.iloc[house_index_region]['attributes.body']
    relevance_score_region = cos_sim_region[0][house_index_region]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_region}, Subject: {house_subject_region}, Body: {house_body_region}, Relevance Score: {relevance_score_region:.2f}")

# Using collaborative filtering for hybrid recommendations
# Transform user input into the latent feature space
user_latent_representation = tfidf_vectorizer.transform([user_document])
user_latent_representation = model_melaka.transform(user_latent_representation)

# Calculate cosine similarity between user input and reconstructed properties data in the specified region
cos_sim_hybrid = cosine_similarity(user_latent_representation, X_reconstructed_region)

# Get indices of properties in the specified region sorted by relevance for hybrid filtering
sorted_indices_hybrid = cos_sim_hybrid.argsort()[0][::-1]

# Print top 5 most relevant houses in the specified region using hybrid filtering
print("Hybrid Recommendations in the specified region:")
for i in range(5):
    house_index_hybrid = sorted_indices_hybrid[i]
    house_category_hybrid = df_region.iloc[house_index_hybrid]['attributes.category_name']
    house_subject_hybrid = df_region.iloc[house_index_hybrid]['attributes.subject']
    house_body_hybrid = df_region.iloc[house_index_hybrid]['attributes.body']
    relevance_score_hybrid = cos_sim_hybrid[0][house_index_hybrid]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_hybrid}, Subject: {house_subject_hybrid}, Body: {house_body_hybrid}, Relevance Score: {relevance_score_hybrid:.2f}")
# Out:
# Unique Regions: ['johor' 'melaka' 'negeri sembilan']
# Enter your preferred number of bedroom:
# Enter your preferred price range(RM):
# Enter keywords to search for house:  flat,negeri sembilan
# C:\Users\User\AppData\Local\Temp\ipykernel_20284\953883313.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_region['text'] = df_region[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
# Content-Based Recommendations in the specified region:
# 1. Category: apartment condominium, Subject: flat bilik untuk dijual, Body: flat seri rasah bilik untuk dijual 59k berdekatan uitm s3 contact, Relevance Score: 0.59
# 2. Category: apartment condominium, Subject: flat rasah jaya ground floor, Body: flat rasah jaya seremban sale ground floor hot selling basic unit 100k call info 017-2256630 arasi, Relevance Score: 0.49
# 3. Category: apartment condominium, Subject: flat nibong sikamat n9 murah untuk dijual, Body: wts flat termurah taman bukit nibong sikamat seremban tenure freehold bumi bilik bilik air tingkat saiz sqft asking price rm75k nego, Relevance Score: 0.47
# 4. Category: apartment condominium, Subject: flat murah tingkat cempaka seremban utk dijual, Body: 2nd floor flat sale seremban lokasi cempaka b jalan s2 g5 garden avenue seremban seremban n.9 harga rm95,000 information interested buying selling property kindly contact mr chew, Relevance Score: 0.47
# 5. Category: apartment condominium, Subject: flat house sale, Body: flat house sale nilai block jalan perdana nilai ground floor corner lot please whatsapp 016-2931336, Relevance Score: 0.45
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 99
#      96 # Using collaborative filtering for hybrid recommendations
#      97 # Transform user input into the latent feature space
#      98 user_latent_representation = tfidf_vectorizer.transform([user_document])
# ---> 99 user_latent_representation = model_melaka.transform(user_latent_representation)
#     101 # Calculate cosine similarity between user input and reconstructed properties data in the specified region
#     102 cos_sim_hybrid = cosine_similarity(user_latent_representation, X_reconstructed_region)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\decomposition\_nmf.py:1794, in NMF.transform(self, X)
#    1780 """Transform the data X according to the fitted NMF model.
#    1781
#    1782 Parameters
#    (...)
#    1791     Transformed data.
#    1792 """
#    1793 check_is_fitted(self)
# -> 1794 X = self._validate_data(
#    1795     X, accept_sparse=("csr", "csc"), dtype=[np.float64, np.float32], reset=False
#    1796 )
#    1798 with config_context(assume_finite=True):
#    1799     W, *_ = self._fit_transform(X, H=self.components_, update_H=False)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 22292 features, but NMF is expecting 5 features as input.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv("response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Reconstruction of X from the factorized matrices
X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)

# Calculate RMSE for Melaka
rmse_melaka = np.sqrt(np.mean((X_melaka - X_reconstructed_melaka)**2))

# Load data for content-based filtering
file_path = "mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)

# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Get user input for keywords
keywords_input = input("Enter keywords to search for house: ")
keywords = keywords_input.split(',')

# Filter the dataset to include only properties from the specified region
df_region = df[df['attributes.region_name'].str.lower().isin(keywords)]
X_region = X_melaka  # Using collaborative filtering data for Melaka

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df_region['text'] = df_region[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix_region = tfidf_vectorizer.fit_transform(df_region['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data in the specified region
cos_sim_region = cosine_similarity(user_vector, tfidf_matrix_region)

# Get indices of properties in the specified region sorted by relevance
sorted_indices_region = cos_sim_region.argsort()[0][::-1]

# Print top 5 most relevant houses in the specified region
print("Content-Based Recommendations in the specified region:")
for i in range(5):
    house_index_region = sorted_indices_region[i]
    house_category_region = df_region.iloc[house_index_region]['attributes.category_name']
    house_subject_region = df_region.iloc[house_index_region]['attributes.subject']
    house_body_region = df_region.iloc[house_index_region]['attributes.body']
    relevance_score_region = cos_sim_region[0][house_index_region]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_region}, Subject: {house_subject_region}, Body: {house_body_region}, Relevance Score: {relevance_score_region:.2f}")

# Using collaborative filtering for hybrid recommendations
# Transform user input into the latent feature space using the TF-IDF vectorizer
user_latent_representation = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and reconstructed properties data in the specified region
cos_sim_hybrid = cosine_similarity(user_latent_representation, X_region)

# Get indices of properties in the specified region sorted by relevance for hybrid filtering
sorted_indices_hybrid = cos_sim_hybrid.argsort()[0][::-1]

# Print top 5 most relevant houses in the specified region using hybrid filtering
print("Hybrid Recommendations in the specified region:")
for i in range(5):
    house_index_hybrid = sorted_indices_hybrid[i]
    house_category_hybrid = df_region.iloc[house_index_hybrid]['attributes.category_name']
    house_subject_hybrid = df_region.iloc[house_index_hybrid]['attributes.subject']
    house_body_hybrid = df_region.iloc[house_index_hybrid]['attributes.body']
    relevance_score_hybrid = cos_sim_hybrid[0][house_index_hybrid]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_hybrid}, Subject: {house_subject_hybrid}, Body: {house_body_hybrid}, Relevance Score: {relevance_score_hybrid:.2f}")
# Out:
# Unique Regions: ['johor' 'melaka' 'negeri sembilan']
# Enter your preferred number of bedroom:
# Enter your preferred price range(RM):
# Enter keywords to search for house:  johor,bungalow
# C:\Users\User\AppData\Local\Temp\ipykernel_20284\3933138537.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_region['text'] = df_region[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
# Content-Based Recommendations in the specified region:
# 1. Category: house, Subject: double storey bungalow taman universiti desa skudai, Body: bungalow desa skudai near taman universiti mutiara rini double storey bungalow freehold bumilot northwest land size 7,600 sqft 80x95 build 3,700 sqft room bathroom selling price rm 1.38m please contact jack, Relevance Score: 0.60
# 2. Category: house, Subject: bungalow taman daya sale non bumi lot, Body: sale bungalow non bumi lot sale bungalow land size sqft built size sqft renovation yes status leasehold non bumi lot asking price rm800k nego bank value match bedroom bathroom welcome call arrange viewing owner welcome list  kindly contact azuandy aradi 019-7133228, Relevance Score: 0.59
# 3. Category: house, Subject: taman suria bungalow town jb johor double storey larkin sale, Body: sale taman suria johor double storey bungalow bedroom bathroom land size x built sqft facing southwest international lot freehold unblock view unit ~selling price rm 1.3 mil ~kindly contact m kimi 010-8859619, Relevance Score: 0.56
# 4. Category: house, Subject: leisure farm bungalow jalan pinang guard bungalow sale, Body: sale leisure farm bungalow jalan pinang storey bungalow land area 18,083sqf built sqft including carporch balcony rear terrace entrance bedroom +1 maid room lounge bathroom freehold international lot guard gated ~selling price rm 5mil ~kindly contact m kimi 010-8859619, Relevance Score: 0.55
# 5. Category: house, Subject: double storey bungalow house taman desa skudai johor, Body: bungalow house sale  double storey bungalow house taman desa skudai johor  asking price rm1,250,000 negotiable contact izwan ibrahim  property detail  type double storey bungalow status freehold bumi lot build sqft land area x sqft bedroom store bathroom feel free contact interested izwan ibrahim ren iqi realty sdn bhd http //wa.me/60177030022 pemilik rumah juga dialu-alukan untuk menghubungi saya sekiranya ingin menjual/menyewakan hartanah anda, Relevance Score: 0.55
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 90
#      87 user_latent_representation = tfidf_vectorizer.transform([user_document])
#      89 # Calculate cosine similarity between user input and reconstructed properties data in the specified region
# ---> 90 cos_sim_hybrid = cosine_similarity(user_latent_representation, X_region)
#      92 # Get indices of properties in the specified region sorted by relevance for hybrid filtering
#      93 sorted_indices_hybrid = cos_sim_hybrid.argsort()[0][::-1]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:1657, in cosine_similarity(X, Y, dense_output)
#    1613 """Compute cosine similarity between samples in X and Y.
#    1614
#    1615 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1653        [0.57..., 0.81...]])
#    1654 """
#    1655 # to avoid recursive import
# -> 1657 X, Y = check_pairwise_arrays(X, Y)
#    1659 X_normalized = normalize(X, copy=True)
#    1660 if X is Y:
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:189, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     183         raise ValueError(
#     184             "Precomputed metric requires shape "
#     185             "(n_queries, n_indexed). Got (%d, %d) "
#     186             "for %d indexed." % (X.shape[0], X.shape[1], Y.shape[0])
#     187         )
#     188 elif X.shape[1] != Y.shape[1]:
# --> 189     raise ValueError(
#     190         "Incompatible dimension for X and Y matrices: "
#     191         "X.shape[1] == %d while Y.shape[1] == %d" % (X.shape[1], Y.shape[1])
#     192     )
#     194 return X, Y
#
# ValueError: Incompatible dimension for X and Y matrices: X.shape[1] == 19040 while Y.shape[1] == 5

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF
import numpy as np

# Load data for collaborative filtering
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Preprocess the data if necessary
# For example, handle missing values or clean the data

# Create User-Item Matrix for Melaka
user_item_matrix_melaka = pd.pivot_table(data, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')

# Fill missing values with 0 for Melaka
user_item_matrix_melaka.fillna(0, inplace=True)

# Convert Melaka user-item matrix to numpy array
X_melaka = user_item_matrix_melaka.values

# Initialize and fit NMF model for Melaka
num_components = 20  # Number of latent factors
model_melaka = NMF(n_components=num_components, init='random', random_state=20)
W_melaka = model_melaka.fit_transform(X_melaka)  # Factorization of X_melaka into W_melaka and H_melaka

# Load data for content-based filtering
file_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
df = pd.read_csv(file_path)

# Print unique regions for debugging
unique_regions = df['attributes.region_name'].unique()
print("Unique Regions:", unique_regions)

# Prompt the user to input preferences
bedroom_size = input("Enter your preferred number of bedroom: ")
price_range = input("Enter your preferred price range(RM): ")

# Get user input for keywords
keywords_input = input("Enter keywords to search for house: ")
keywords = keywords_input.split(',')

# Filter the dataset to include only properties from the specified region
# Filter the dataset to include only properties from the specified region
if 'johor' in unique_regions and 'johor' in keywords_input.lower():
    df_region = df[df['attributes.region_name'].str.lower() == 'johor']
    # Create User-Item Matrix for Johor
    user_item_matrix_johor = pd.pivot_table(df_region, values=['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')
    # Fill missing values with 0 for Johor
    user_item_matrix_johor.fillna(0, inplace=True)

elif 'melaka' in unique_regions and 'melaka' in keywords_input.lower():
    df_region = df[df['attributes.region_name'].str.lower() == 'melaka']
    X_region = X_melaka  # Using collaborative filtering data for Melaka
elif 'negeri sembilan' in unique_regions and 'negeri sembilan' in keywords_input.lower():
    df_region = df[df['attributes.region_name'].str.lower() == 'negeri sembilan']
    # Create User-Item Matrix for Negeri Sembilan
    user_item_matrix_negeri_sembilan = pd.pivot_table(df_region, values=['traffic\n.1', 'air_pollution\n.1', 'sound_pollution.1', 'crime_rate.1', 'overall_rating.1'], index='Username')
    # Fill missing values with 0 for Negeri Sembilan
    user_item_matrix_negeri_sembilan.fillna(0, inplace=True)
    # Convert Negeri Sembilan user-item matrix to numpy array
    X_negeri_sembilan = user_item_matrix_negeri_sembilan.values
    # Initialize and fit NMF model for Negeri Sembilan
    model_negeri_sembilan = NMF(n_components=num_components, init='random', random_state=20)
    W_negeri_sembilan = model_negeri_sembilan.fit_transform(X_negeri_sembilan)  # Factorization of X_negeri_sembilan into W_negeri_sembilan and H_negeri_sembilan
else:
    print("Region specified in the user input is not available in the dataset.")
    # You might want to handle this case differently based on your requirements
    exit()

# Concatenate the selected columns into a single text column for content-based filtering
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df_region['text'] = df_region[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize TfidfVectorizer for content-based filtering
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix_region = tfidf_vectorizer.fit_transform(df_region['text'])

# Transform user input into a document
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and properties data in the specified region
cos_sim_region = cosine_similarity(user_vector, tfidf_matrix_region)

# Get indices of properties in the specified region sorted by relevance
sorted_indices_region = cos_sim_region.argsort()[0][::-1]

# Initialize variables for storing latent representations of properties in each region
X_reconstructed_johor = None
X_reconstructed_melaka = None
X_reconstructed_negeri_sembilan = None

# Reconstruct properties data in the specified region using NMF components
if 'johor' in unique_regions and 'johor' in keywords_input.lower():
    X_reconstructed_johor = np.dot(W_johor, model_johor.components_)
elif 'melaka' in unique_regions and 'melaka' in keywords_input.lower():
    X_reconstructed_melaka = np.dot(W_melaka, model_melaka.components_)
elif 'negeri sembilan' in unique_regions and 'negeri sembilan' in keywords_input.lower():
    X_reconstructed_negeri_sembilan = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_)

# Select the reconstructed properties data based on the specified region
X_reconstructed_region = X_reconstructed_johor if 'johor' in keywords_input.lower() else X_reconstructed_melaka if 'melaka' in keywords_input.lower() else X_reconstructed_negeri_sembilan

# Calculate cosine similarity between user input and reconstructed properties data in the specified region
cos_sim_hybrid = cosine_similarity(user_vector, X_reconstructed_region)

# Get indices of properties in the specified region sorted by relevance for hybrid filtering
sorted_indices_hybrid = cos_sim# Get indices of properties in the specified region sorted by relevance for hybrid filtering
sorted_indices_hybrid = cos_sim_hybrid.argsort()[0][::-1]

# Print top 5 most relevant houses in the specified region using hybrid filtering
print("Hybrid Recommendations in the specified region:")
for i in range(5):
    house_index_hybrid = sorted_indices_hybrid[i]
    house_category_hybrid = df_region.iloc[house_index_hybrid]['attributes.category_name']
    house_subject_hybrid = df_region.iloc[house_index_hybrid]['attributes.subject']
    house_body_hybrid = df_region.iloc[house_index_hybrid]['attributes.body']
    relevance_score_hybrid = cos_sim_hybrid[0][house_index_hybrid]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_hybrid}, Subject: {house_subject_hybrid}, Body: {house_body_hybrid}, Relevance Score: {relevance_score_hybrid:.2f}")

# Print top 5 most relevant houses in the specified region using content-based filtering
print("Content-Based Recommendations in the specified region:")
for i in range(5):
    house_index_region = sorted_indices_region[i]
    house_category_region = df_region.iloc[house_index_region]['attributes.category_name']
    house_subject_region = df_region.iloc[house_index_region]['attributes.subject']
    house_body_region = df_region.iloc[house_index_region]['attributes.body']
    relevance_score_region = cos_sim_region[0][house_index_region]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_region}, Subject: {house_subject_region}, Body: {house_body_region}, Relevance Score: {relevance_score_region:.2f}")

# Using collaborative filtering for hybrid recommendations
# Transform user input into the latent feature space using the TF-IDF vectorizer
user_latent_representation = tfidf_vectorizer.transform([user_document])

# Reconstruct properties data in the specified region using NMF components
X_reconstructed_region = np.dot(W_johor, model_johor.components_) if 'johor' in unique_regions and 'johor' in keywords_input.lower() else X_reconstructed_johor
X_reconstructed_region = np.dot(W_melaka, model_melaka.components_) if 'melaka' in unique_regions and 'melaka' in keywords_input.lower() else X_reconstructed_melaka
X_reconstructed_region = np.dot(W_negeri_sembilan, model_negeri_sembilan.components_) if 'negeri sembilan' in unique_regions and 'negeri sembilan' in keywords_input.lower() else X_reconstructed_negeri_sembilan

# Calculate cosine similarity between user input and reconstructed properties data in the specified region
cos_sim_hybrid = cosine_similarity(user_latent_representation, X_reconstructed_region)

# Get indices of properties in the specified region sorted by relevance for hybrid filtering
sorted_indices_hybrid = cos_sim_hybrid.argsort()[0][::-1]

# Print top 5 most relevant houses in the specified region using hybrid filtering
print("Hybrid Recommendations in the specified region:")
for i in range(5):
    house_index_hybrid = sorted_indices_hybrid[i]
    house_category_hybrid = df_region.iloc[house_index_hybrid]['attributes.category_name']
    house_subject_hybrid = df_region.iloc[house_index_hybrid]['attributes.subject']
    house_body_hybrid = df_region.iloc[house_index_hybrid]['attributes.body']
    relevance_score_hybrid = cos_sim_hybrid[0][house_index_hybrid]
    
    # Display the recommendation
    print(f"{i+1}. Category: {house_category_hybrid}, Subject: {house_subject_hybrid}, Body: {house_body_hybrid}, Relevance Score: {relevance_score_hybrid:.2f}")
# Out:
# Unique Regions: ['johor' 'melaka' 'negeri sembilan']
# Enter your preferred number of bedroom:
# Enter your preferred price range(RM):
# Enter keywords to search for house:  johor,condo
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 48
#      46 df_region = df[df['attributes.region_name'].str.lower() == 'johor']
#      47 # Create User-Item Matrix for Johor
# ---> 48 user_item_matrix_johor = pd.pivot_table(df_region, values=['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')
#      49 # Fill missing values with 0 for Johor
#      50 user_item_matrix_johor.fillna(0, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'traffic'

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Read data from CSV file
file_path = r"C:\Users\User\Desktop\response.csv"
data = pd.read_csv(r"C:\Users\User\Desktop\response.csv")

# Display column names
print("Column Names:")
print(df.columns)

# Concatenate the selected columns into a single text column
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
df = pd.read_csv(file_path)
df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)



# Collaborative Filtering
def collaborative_filtering(data):
    # Preprocess the data if necessary
    # Create User-Item Matrix
    user_item_matrix = pd.pivot_table(data, values=['traffic\n', 'air_pollution\n', 'sound_pollution', 'crime_rate', 'overall_rating'], index='Username')
    # Fill missing values with 0
    user_item_matrix.fillna(0, inplace=True)
    # Convert to numpy array
    X = user_item_matrix.values
    # Initialize and fit NMF model
    num_components = 20  # Number of latent factors
    model = NMF(n_components=num_components, init='random', random_state=20)
    W = model.fit_transform(X)
    # Reconstruction of X from the factorized matrices
    X_reconstructed = np.dot(W, model.components_)
    return X_reconstructed

# Content-Based Filtering
def content_based_filtering(df, user_input):
    # Initialize TfidfVectorizer
    tfidf_vectorizer = TfidfVectorizer()
    # Fit and transform the text data
    tfidf_matrix = tfidf_vectorizer.fit_transform(df['text'])
    # Transform user input into a document
    user_document = ' '.join(user_input)
    user_vector = tfidf_vectorizer.transform([user_document])
    # Calculate cosine similarity between user input and properties data
    cos_sim = cosine_similarity(user_vector, tfidf_matrix)
    return cos_sim

# Hybrid Filtering
def hybrid_filtering(data, df, user_input):
    # Collaborative Filtering
    X_reconstructed = collaborative_filtering(data)
    # Content-Based Filtering
    cos_sim = content_based_filtering(df, user_input)
    # Combine recommendations from both methods
    hybrid_scores = (X_reconstructed + cos_sim) / 2
    # Get indices of properties sorted by relevance
    sorted_indices = hybrid_scores.argsort()[0][::-1]
    return sorted_indices

# Get user input for keywords
keywords = input("Enter keywords to search for house: ").split()

# Get hybrid recommendations
sorted_indices = hybrid_filtering(data, df, keywords)

# Print top 5 most relevant houses
print("Top 5 most relevant houses:")
for i in range(5):
    house_index = sorted_indices[i]
    house_category = df.iloc[house_index]['attributes.category_name']
    house_subject = df.iloc[house_index]['attributes.subject']
    house_body = df.iloc[house_index]['attributes.body']
    house_region = df.iloc[house_index]['attributes.region_name']
    house_property_type = df.iloc[house_index]['attributes.property_type_name']
    relevance_score = hybrid_scores[0][house_index]
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Relevance Score: {relevance_score:.2f})")
# Out:
# Column Names:
# Index(['Timestamp', 'Username', 'Name', 'Gender', 'Marital Status',
#        'Please select your age group', 'Occupation',
#        'In which state are you currently staying, or have you been staying?',
#        'Where do you live in Johor', 'traffic\n', 'air_pollution_johor\n',
#        'sound_pollution_johor', 'crime_rate_johor', 'overall_rating_johor',
#        'Review_johor', 'Where do you live in Melaka', 'traffic_melaka\n',
#        'air_pollution_melaka\n', 'sound_pollution_melaka', 'crime_rate_melaka',
#        'overall_rating_melaka', 'Review_melaka',
#        'Where do you live in Negeri Sembilan', 'traffic_ns\n',
#        'air_pollution_ns\n', 'sound_pollution_ns', 'crime_rate_ns',
#        'overall_rating_ns', 'Review_ns'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 18
#      16 selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
#      17 df = pd.read_csv(file_path)
# ---> 18 df['text'] = df[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
#      22 # Collaborative Filtering
#      23 def collaborative_filtering(data):
#      24     # Preprocess the data if necessary
#      25     # Create User-Item Matrix
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['attributes.category_name', 'attributes.subject', 'attributes.body',\n       'attributes.region_name', 'attributes.property_type_name'],\n      dtype='object')] are in the [columns]"

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# Concatenate selected columns into a single text column
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
house_data['text'] = house_data[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# User input for keywords
keywords = input("Enter keywords to search for a house: ").split()

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(house_data['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Preprocess ratings data if necessary

# Function to calculate collaborative filtering scores
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    return 1 / (1 + rmse)

# Calculate collaborative filtering scores for each region
collab_scores = {}
for region in ['Johor', 'Melaka', 'Negeri Sembilan']:
    user_item_matrix = pd.pivot_table(ratings_data, values=[f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']], index='Username')
    collab_scores[region] = calculate_collab_score(user_item_matrix)

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for region, index in zip(['Johor', 'Melaka', 'Negeri Sembilan'], [sorted_indices[:5], sorted_indices[5:10], sorted_indices[10:15]]):
    for i, house_index in enumerate(index):
        content_score = cos_sim[0][house_index]
        collab_score = collab_scores[region]
        combined_score = (content_weight * content_score) + (collab_weight * collab_score)
        combined_scores[(region, i+1)] = {
            "House Index": house_index,
            "Combined Score": combined_score
        }

# Sort combined scores and print the top 5 houses
print("\nTop 5 Houses based on Hybrid Filtering:")
sorted_combined_scores = sorted(combined_scores.items(), key=lambda x: x[1]['Combined Score'], reverse=True)[:5]
for i, (region, house_data) in enumerate(sorted_combined_scores):
    house_index = house_data['House Index']
    house_category = house_data['attributes.category_name']
    house_subject = house_data['attributes.subject']
    house_body = house_data['attributes.body']
    house_region = house_data['attributes.region_name']
    house_property_type = house_data['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Combined Score: {house_data['Combined Score']:.2f})")
# Out:
# Enter keywords to search for a house:  melaka,flat
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 51
#      49 collab_scores = {}
#      50 for region in ['Johor', 'Melaka', 'Negeri Sembilan']:
# ---> 51     user_item_matrix = pd.pivot_table(ratings_data, values=[f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']], index='Username')
#      52     collab_scores[region] = calculate_collab_score(user_item_matrix)
#      54 # Weight for each method (content-based and collaborative)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'traffic.johor'

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# Concatenate selected columns into a single text column
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
house_data['text'] = house_data[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# User input for keywords
keywords = input("Enter keywords to search for a house: ").split()

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(house_data['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Function to calculate collaborative filtering scores
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    return 1 / (1 + rmse)

# Calculate collaborative filtering scores for each region
collab_scores = {}
for region in ['Johor', 'Melaka', 'Negeri Sembilan']:
    metrics = [f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']]
    if all(metric in ratings_data.columns for metric in metrics):
        user_item_matrix = pd.pivot_table(ratings_data, values=metrics, index='Username')
        collab_scores[region] = calculate_collab_score(user_item_matrix)

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for region, index in zip(['Johor', 'Melaka', 'Negeri Sembilan'], [sorted_indices[:5], sorted_indices[5:10], sorted_indices[10:15]]):
    for i, house_index in enumerate(index):
        content_score = cos_sim[0][house_index]
        if region in collab_scores:
            collab_score = collab_scores[region]
            combined_score = (content_weight * content_score) + (collab_weight * collab_score)
        else:
            combined_score = content_score
        combined_scores[(region, i+1)] = {
            "House Index": house_index,
            "Combined Score": combined_score
        }

# Sort combined scores and print the top 5 houses
print("\nTop 5 Houses based on Hybrid Filtering:")
sorted_combined_scores = sorted(combined_scores.items(), key=lambda x: x[1]['Combined Score'], reverse=True)[:5]
for i, (region, house_data) in enumerate(sorted_combined_scores):
    house_index = house_data['House Index']
    house_category = house_data['attributes.category_name']
    house_subject = house_data['attributes.subject']
    house_body = house_data['attributes.body']
    house_region = house_data['attributes.region_name']
    house_property_type = house_data['attributes.property_type_name']
    relevance_score = cos_sim[0][house_index]
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Combined Score: {house_data['Combined Score']:.2f})")
# Out:
# Enter keywords to search for a house:  johor
# Top 5 Houses based on Hybrid Filtering:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 78
#      76 for i, (region, house_data) in enumerate(sorted_combined_scores):
#      77     house_index = house_data['House Index']
# ---> 78     house_category = house_data['attributes.category_name']
#      79     house_subject = house_data['attributes.subject']
#      80     house_body = house_data['attributes.body']
#
# KeyError: 'attributes.category_name'

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# Concatenate selected columns into a single text column
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
house_data['text'] = house_data[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# User input for keywords
keywords = input("Enter keywords to search for a house: ").split()

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(house_data['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords)
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Function to calculate collaborative filtering scores
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    return 1 / (1 + rmse)

# Calculate collaborative filtering scores for each region
collab_scores = {}
for region in ['Johor', 'Melaka', 'Negeri Sembilan']:
    metrics = [f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']]
    if all(metric in ratings_data.columns for metric in metrics):
        user_item_matrix = pd.pivot_table(ratings_data, values=metrics, index='Username')
        collab_scores[region] = calculate_collab_score(user_item_matrix)

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for region, index in zip(['Johor', 'Melaka', 'Negeri Sembilan'], [sorted_indices[:5], sorted_indices[5:10], sorted_indices[10:15]]):
    for i, house_index in enumerate(index):
        content_score = cos_sim[0][house_index]
        if region in collab_scores:
            collab_score = collab_scores[region]
            combined_score = (content_weight * content_score) + (collab_weight * collab_score)
        else:
            combined_score = content_score
        combined_scores[(region, i+1)] = {
            "House Index": house_index,
            "Combined Score": combined_score
        }

# Sort combined scores and print the top 5 houses
print("\nTop 15 Houses based on Hybrid Filtering:")
for i, (region, data) in enumerate(combined_scores.items()):
    house_index = data['House Index']
    house_category = house_data.iloc[house_index]['attributes.category_name']
    house_subject = house_data.iloc[house_index]['attributes.subject']
    house_body = house_data.iloc[house_index]['attributes.body']
    house_region = house_data.iloc[house_index]['attributes.region_name']
    house_property_type = house_data.iloc[house_index]['attributes.property_type_name']
    print(f"{i+1}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Combined Score: {data['Combined Score']:.2f})")
# Out:
# Enter keywords to search for a house:  apartment,johor
# Top 15 Houses based on Hybrid Filtering:
# 1. Category: apartment condominium, Subject: apartment sell, Body: selling furnished renovation price nego, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.61)
# 2. Category: apartment condominium, Subject: apartment sale, Body: apartment sale cempaka court 3rd floor, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.58)
# 3. Category: apartment condominium, Subject: ara ria apartment, Body: negotiable, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.54)
# 4. Category: apartment condominium, Subject: villa krystall room apartment, Body: bumi lot call, Region: johor, Property Type: apartment (Combined Score: 0.53)
# 5. Category: apartment condominium, Subject: bukit saujana apartment, Body: apartment saujana jb pahlawan bukit saujana apartment tingkat keluasan sq foot 3 room 2 bathroom, Region: johor, Property Type: apartment (Combined Score: 0.50)
# 6. Category: apartment condominium, Subject: sale vista seri alam apartment, Body: ground floor parking lot back yard side, Region: johor, Property Type: apartment (Combined Score: 0.47)
# 7. Category: apartment condominium, Subject: apartment dahlia seremban, Body: apartment dahlia q sale 3rd floor non bumi lot bedroom ,1 bathroom ,1 toilet fully tile, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.46)
# 8. Category: apartment condominium, Subject: beach apartment, Body: foot beach, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.45)
# 9. Category: apartment condominium, Subject: pine residence room sell, Body: market value full loan call, Region: johor, Property Type: apartment (Combined Score: 0.44)
# 10. Category: apartment condominium, Subject: freehold apartment bukit beruang, Body: freehold apartment high rental suitable investment 990sqft pm call detail viewing welcomed, Region: melaka, Property Type: apartment (Combined Score: 0.43)
# 11. Category: apartment condominium, Subject: skudai villa apartment skudai full loan, Body: sale location skudai villa apartment skudai type apartment level bedroom bathroom built 831sqft freehold international lot guard gated selling price rm235k  alvin ng, Region: johor, Property Type: apartment (Combined Score: 0.43)
# 12. Category: apartment condominium, Subject: sri sena apartment, Body: apartment sq ft come bedroom bathroom kitchen full furnished selling house furniture included call w pn ida, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.43)
# 13. Category: apartment condominium, Subject: villa krystal apartment skudai full loan, Body: for sale apartment viewing time day advance bank value 280k high floor balcony block b sale rm 230k address jalan silat lincah bandar selesa jaya johor bahru johor type apartment unit type residence tenure freehold non bumi bedroom +1 bathroom land size sqft built renovation original furnishing unfurnished facing pool view direction g g yes car park neighbor maintenance fee house year reason sale upgrade, Region: johor, Property Type: apartment (Combined Score: 0.41)
# 14. Category: apartment condominium, Subject: apartment, Body: apartment spacious high ceiling large window open balcony beautiful view beach three-bedroom sq ft. apartment conveniently located glory beach resort 5.6 kilometre port dickson town centre fully furnished apartment ready stay let hesitate call owner viewing negotiable, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.41)
# 15. Category: apartment condominium, Subject: apartment sale east bay masai high floor, Body: apartment sale east bay apartment -3 bedroom -2 bathroom -partially furnished -1097sqft -freehold -1 car park -high floor asking price rm360k janice yong  +601111166569 the roof realty tag, Region: johor, Property Type: apartment (Combined Score: 0.40)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# User input for keywords and region
keywords_region = input("Enter keywords and region (e.g., 'apartment,johor'): ")
keywords, region = keywords_region.split(',')

# Filter houses from the specified region
region_filter = house_data['attributes.region_name'].str.lower() == region.strip().lower()
region_houses = house_data[region_filter]

# Concatenate selected columns into a single text column
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
region_houses['text'] = region_houses[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(region_houses['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords.split())
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Function to calculate collaborative filtering scores
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    return 1 / (1 + rmse)

# Calculate collaborative filtering scores for the specified region
collab_scores = {}
metrics = [f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']]
if all(metric in ratings_data.columns for metric in metrics):
    user_item_matrix = pd.pivot_table(ratings_data, values=metrics, index='Username')
    collab_scores[region] = calculate_collab_score(user_item_matrix)

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for i, house_index in enumerate(sorted_indices[:15]):
    content_score = cos_sim[0][house_index]
    if region in collab_scores:
        collab_score = collab_scores[region]
        combined_score = (content_weight * content_score) + (collab_weight * collab_score)
    else:
        combined_score = content_score
    combined_scores[i+1] = {
        "House Index": house_index,
        "Combined Score": combined_score
    }

# Sort combined scores and print the top 15 houses
print("\nTop 15 Houses based on Hybrid Filtering:")
for i, data in combined_scores.items():
    house_index = data['House Index']
    house_category = region_houses.iloc[house_index]['attributes.category_name']
    house_subject = region_houses.iloc[house_index]['attributes.subject']
    house_body = region_houses.iloc[house_index]['attributes.body']
    house_region = region_houses.iloc[house_index]['attributes.region_name']
    house_property_type = region_houses.iloc[house_index]['attributes.property_type_name']
    print(f"{i}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Combined Score: {data['Combined Score']:.2f})")
# Out:
# Enter keywords and region (e.g., 'apartment,johor'):  flat,melaka
# C:\Users\User\AppData\Local\Temp\ipykernel_11384\396591051.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   region_houses['text'] = region_houses[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
# Top 15 Houses based on Hybrid Filtering:
# 1. Category: apartment condominium, Subject: cheng ria flat sale, Body: near shop easy access highway good environment, Region: melaka, Property Type: flat (Combined Score: 0.62)
# 2. Category: apartment condominium, Subject: banda hilir flat sale, Body: banda hilir flat sale view please contact 014-3384930, Region: melaka, Property Type: flat (Combined Score: 0.56)
# 3. Category: apartment condominium, Subject: 3rd floor taman merdeka jaya flat batu berendam melaka, Body: flat taman merdeka jaya melaka sale rm110k level sqft bedroom bathroom leasehold non bumi chester property sdn bhd 016-666 raymond 010-277 lawrence ren59994, Region: melaka, Property Type: flat (Combined Score: 0.52)
# 4. Category: apartment condominium, Subject: malim flat good invesment rental go, Body: sale malim flat lvl lh 65+- 668sqft 3bedroom 1bathroom rm88k, Region: melaka, Property Type: flat (Combined Score: 0.49)
# 5. Category: apartment condominium, Subject: nearby infineon rumah pangsa bt berendam, Body:  strategy location  good investment  walk flat  currently tenanted  direct owner, Region: melaka, Property Type: flat (Combined Score: 0.48)
# 6. Category: apartment condominium, Subject: malim jaya flat sale, Body: hi im selling flat rm80k highly nego flat currently empty recently renovated rm20k last year since 's empty call whatsapp +60126027807 dato kannan information, Region: melaka, Property Type: apartment (Combined Score: 0.44)
# 7. Category: apartment condominium, Subject: pangsapuri bachang flat, Body: pangsapuri bachang flat sale -freehold -688sq.ft -3 bedroom -2 bathroom -walk -3min family store -3min kopitiam shop lot -5min go kg -10 min go shopping center detail pls whatsapp sim, Region: melaka, Property Type: flat (Combined Score: 0.42)
# 8. Category: apartment condominium, Subject: high floor taman anika flat kenanga kampung lapan melaka, Body: melaka subsale taman anika flat kenanga kampung lapan melaka level flat size sq.ft bedroom bathroom leasehold non bumi lot facing empty land rm 78,000 rm 78,000 rm 78,000 detail/viewing please call vinc pheng ren contact 017-6267 disclaimer protect owner tenant 's privacy photo reference might actual picture appreciate understanding viewing thanks, Region: melaka, Property Type: flat (Combined Score: 0.42)
# 9. Category: apartment condominium, Subject: flat pangsapuri merdeka batu berendam, Body: flat sale pangsapuri merdeka batu berendam 710sqft leasehold non bumi lot bedroom bathroom level walk apartment rm 108,000 019-6963111 fiona woon 018-2336999 wasap.my/60196963111 provide loan service lawyer panel property wanted shop/house/land/factory sale/rent owner welcome call provide check market value property got ready buyer tenant database melaka fiona woon -ren meridin property sdn bhd, Region: melaka, Property Type: flat (Combined Score: 0.40)
# 10. Category: apartment condominium, Subject: flat rumah pangsa taman merdeka batu berendam melaka, Body: walk flat sale rumah pangsa taman merdeka batu berendam melaka 645sqft leasehold non bumi lot bedroom bathroom rm 88,000 019-6963111 fiona woon 018-2336999 wasap.my/60196963111 provide loan service lawyer panel property wanted shop/house/land/factory sale/rent owner welcome call provide check market value property got ready buyer tenant database melaka fiona woon -ren meridin property sdn bhd, Region: melaka, Property Type: flat (Combined Score: 0.39)
# 11. Category: apartment condominium, Subject: taman anika flat lorong pandan kampung lapan near kota laksamana, Body: taman anika walk flat sale lorong pandan melaka asking price rm 70,000 -leasehold -non bumi lot -520 sqft -2 bedroom bathroom -basic renovation unit -well maintained -melaka hot area may also call house inquiry others house ready rent/sale provide bank loan lawyer service for detail/viewing please call/whatsapp 010-2109350 joanne ren fb page jh property, Region: melaka, Property Type: flat (Combined Score: 0.38)
# 12. Category: apartment condominium, Subject: well maintain 3r2b flat duyong melaka, Body: rumah pangsa taman duyong indah duyong melaka leasehold year sqft bedroom bathroom toilet 3rd floor walk good condition    , ramona www.wasap.my/60176105667 ren, Region: melaka, Property Type: flat (Combined Score: 0.36)
# 13. Category: apartment condominium, Subject: flat sale rumah pangsa taman siantan tengkera kampung lapan, Body: flat sale rumah pangsa taman siantan tengkera kampung lapan melaka sqft block b level facing school freehold non bumi lot bedroom bathroom rm 128,000 019-6963111 fiona woon 018-2336999 wasap.my/60196963111 provide loan service lawyer panel property wanted shop/house/land/factory sale/rent owner welcome call provide check market value property got ready buyer tenant database melaka  0196963111 fiona, Region: melaka, Property Type: flat (Combined Score: 0.36)
# 14. Category: apartment condominium, Subject: melaka town taman anika flat 3r2b renovated unit sale, Body: melaka town lorong pandan anika flat level room bathroom leasehold yr renovated unfurnished price rm98,000 nego surrounding primary school shop lot restaurant petrol kiosk clinic etc easy access tengkera kg lapan malim kota laksamana klebang 10min drive lotus aeon hypermarket melaka sentral bus station interested please feel free call whatsapp 019-3030779/012-6400779 bee ren www.wasap.my/60193030779 tq, Region: melaka, Property Type: flat (Combined Score: 0.35)
# 15. Category: apartment condominium, Subject: flat tengkera corner unit renovated melaka town sale, Body: rm100,000 tengkera  flat 3   jalan tengkera melaka walk flat well maintain corner unit room bathroom leasehold 592sq.ft kitchen renovated fully tiled nice table top basin small balcony fully tiled built cabinet pm/ dm direct thru whatsapp wa.me/60169836620 pm/ dm pm/ dm 3 2         100,000 whatsapp wa.me/60169836620 /co broker/agent please  call thanks, Region: melaka, Property Type: flat (Combined Score: 0.35)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# User input for keywords and region
keywords_region = input("Enter keywords and region (e.g., 'apartment,johor'): ")
keywords, region = keywords_region.split(',')

# Filter houses from the specified region
region_filter = house_data['attributes.region_name'].str.lower() == region.strip().lower()
region_houses = house_data[region_filter]

# Concatenate selected columns into a single text column
selected_columns = ['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']
region_houses['text'] = region_houses[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(region_houses['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords.split())
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Function to calculate collaborative filtering scores and RMSE
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    collab_score = 1 / (1 + rmse)
    return collab_score, rmse

# Calculate collaborative filtering scores and RMSE for the specified region
collab_scores = {}
metrics = [f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']]
if all(metric in ratings_data.columns for metric in metrics):
    user_item_matrix = pd.pivot_table(ratings_data, values=metrics, index='Username')
    collab_scores[region], rmse = calculate_collab_score(user_item_matrix)
    print(f"RMSE for {region}: {rmse:.2f}")

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for i, house_index in enumerate(sorted_indices[:15]):
    content_score = cos_sim[0][house_index]
    if region in collab_scores:
        collab_score = collab_scores[region]
        combined_score = (content_weight * content_score) + (collab_weight * collab_score)
    else:
        combined_score = content_score
    combined_scores[i+1] = {
        "House Index": house_index,
        "Combined Score": combined_score
    }

# Sort combined scores and print the top 15 houses
print("\nTop 15 Houses based on Hybrid Filtering:")
for i, data in combined_scores.items():
    house_index = data['House Index']
    house_category = region_houses.iloc[house_index]['attributes.category_name']
    house_subject = region_houses.iloc[house_index]['attributes.subject']
    house_body = region_houses.iloc[house_index]['attributes.body']
    house_region = region_houses.iloc[house_index]['attributes.region_name']
    house_property_type = region_houses.iloc[house_index]['attributes.property_type_name']
    print(f"{i}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Combined Score: {data['Combined Score']:.2f})")
# Out:
# Enter keywords and region (e.g., 'apartment,johor'):  flat,negeri sembilan
# C:\Users\User\AppData\Local\Temp\ipykernel_11384\1063546259.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   region_houses['text'] = region_houses[selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
# Top 15 Houses based on Hybrid Filtering:
# 1. Category: apartment condominium, Subject: flat bilik untuk dijual, Body: flat seri rasah bilik untuk dijual 59k berdekatan uitm s3 contact, Region: negeri sembilan, Property Type: flat (Combined Score: 0.59)
# 2. Category: apartment condominium, Subject: flat rasah jaya ground floor, Body: flat rasah jaya seremban sale ground floor hot selling basic unit 100k call info 017-2256630 arasi, Region: negeri sembilan, Property Type: flat (Combined Score: 0.50)
# 3. Category: apartment condominium, Subject: flat nibong sikamat n9 murah untuk dijual, Body: wts flat termurah taman bukit nibong sikamat seremban tenure freehold bumi bilik bilik air tingkat saiz sqft asking price rm75k nego, Region: negeri sembilan, Property Type: flat (Combined Score: 0.48)
# 4. Category: apartment condominium, Subject: flat murah tingkat cempaka seremban utk dijual, Body: 2nd floor flat sale seremban lokasi cempaka b jalan s2 g5 garden avenue seremban seremban n.9 harga rm95,000 information interested buying selling property kindly contact mr chew, Region: negeri sembilan, Property Type: flat (Combined Score: 0.47)
# 5. Category: apartment condominium, Subject: flat house sale, Body: flat house sale nilai block jalan perdana nilai ground floor corner lot please whatsapp 016-2931336, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.45)
# 6. Category: apartment condominium, Subject: flat nilai perdana bandar baru nilai dekat stesen ktm, Body: flat nilai perdana bandar baru nilai freehold non bumi block j 3rd floor walk low cost floor area sqft room bathroom tenanted near ktm comuter station nilai easy access highway asking price rm 90,000 nego urgent pls contact 013-3440625 rasyadan pea iqi realty, Region: negeri sembilan, Property Type: flat (Combined Score: 0.40)
# 7. Category: apartment condominium, Subject: low cost flat, Body: low density quiet area 1st floor near town near convenient shop near hypermarket near school, Region: negeri sembilan, Property Type: flat (Combined Score: 0.39)
# 8. Category: apartment condominium, Subject: booking 1k dahlia non bumi lot s2 seremban, Body: dahlia flat sale block freehold non bumi lot room 1+1 bathroom balcony level price rm118k nett nego please contact polly, Region: negeri sembilan, Property Type: flat (Combined Score: 0.37)
# 9. Category: apartment condominium, Subject: full renovation flat taman semarak nilai n9, Body: flat taman semarak nilai asking price rm120k detail freehold bumi lot bilik tidur bilik air build 683sqft full renovation plaster ceiling+down light table top +kitchen kabinet toilet new wc +bifold door fully vinyl flooring stratum dalam prose tingkat tiada lif, Region: negeri sembilan, Property Type: flat (Combined Score: 0.37)
# 10. Category: apartment condominium, Subject: flat rasah jaya seremban cantik untuk dijual, Body: fullyrenovated square foot bedroom bathroom freehold non bumi lot asking price rm138,000 negotiable loan application service provided view appointment contact serene casey, Region: negeri sembilan, Property Type: flat (Combined Score: 0.37)
# 11. Category: apartment condominium, Subject: flat ko rendah untuk dijual nilai perdana, Body: flat ko rendah untuk dijual nilai perdana nilai negeri sembilan build 680sqft block j bilik bilik air tingkat bawah berhampiran dengan stesen komuter pekan nilai giant tesco bank-bank komersil dll tenanted ak lebuhraya plus lebuhraya lekas price rm100000 owner reduced price, Region: negeri sembilan, Property Type: flat (Combined Score: 0.37)
# 12. Category: apartment condominium, Subject: s2 dahlia flat top floor good investment easy access town area, Body: sale seremban dahlia flat top floor unit good investment rm k rm k negotiate 650sq bedroom bathroom basic unit fan lightgrilled good condition min jusco min pizza kfc dear property owner property wish sell/rent please feel free contact .. alvinkeong ren 016-2503415 016-2503415 whatsapp infomation http //alvinkeongproperty.wasap.my, Region: negeri sembilan, Property Type: flat (Combined Score: 0.32)
# 13. Category: apartment condominium, Subject: taman bidara flat top floor seremban sale best investment, Body: taman bidara flat top floor seremban sale best investment monthly rental go rm600 detail freehold non bumi lot lift built sqft ori basic unit room bath 3rd floor selling rm70k 2nd floor selling rm85k property wanted dear owner property intend lease sell buy please drop call whatsapp u tq contact viewing appointment alex le 011-2613 ren p/s, Region: negeri sembilan, Property Type: flat (Combined Score: 0.31)
# 14. Category: apartment condominium, Subject: flat dahlia garden avenue seremban market, Body: sale flat low cost dahlia block h garden avenue seremban asking price 110,000 property detail flat low cost freehold bumi lot bedroom bathroom size sq.ft level walk berdekatan sekolah rendah sekolah menengah speedmart eleven kk mart mini market dobi kedai makan hospital kpj hospital colombia kedai makan aeon mall seremban nsk seremban mydin mall seremban family store lotus seremban asking price rm110,000 info viewing appoitment please contact wazif 011-12266033 www.wasap.my/601112266033 mn associate sdn bhd, Region: negeri sembilan, Property Type: apartment (Combined Score: 0.31)
# 15. Category: apartment condominium, Subject: freehold nilai perdana flat block g taman nilai perdana nilai, Body: freehold nilai perdana flat block g taman nilai perdana nilai sale rm 99,000 nego flat freehold non-bumi level walk bedroom bathroom square foot master title sale basic condition unfurnished currently tenanted location google map http //goo.gl/maps/jcmprxguxvfepj8p6 surau al-azim 0.1 km ktm nilai station 1.5 km sk nilai 1.5 km smk dato mohd said 1.7 km masjid lama nilai 1.9 km aeon mall nilai 4.5 km access plus highway deposit 3.18 booking 6.82 upon signing p lawyer valuer arranged whatsapp fit-ri enquiry viewing http //wa.me/60189534295 fit-ri 018-9534295 real estate negotiator ren rescom realty, Region: negeri sembilan, Property Type: flat (Combined Score: 0.30)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# User input for keywords and region
keywords_region = input("Enter keywords and region (e.g., 'apartment,johor'): ")
keywords, region = keywords_region.split(',')

# Filter houses from the specified region
region_filter = house_data['attributes.region_name'].str.lower() == region.strip().lower()
region_houses = house_data[region_filter]

# Concatenate selected columns into a single text column
region_houses['text'] = region_houses[['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(region_houses['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords.split())
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Function to calculate collaborative filtering scores and RMSE
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    collab_score = 1 / (1 + rmse)
    return collab_score, rmse

# Calculate collaborative filtering scores and RMSE for the specified region
collab_scores = {}
metrics = [f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']]
if all(metric in ratings_data.columns for metric in metrics):
    user_item_matrix = pd.pivot_table(ratings_data, values=metrics, index='Username')
    collab_scores[region], rmse = calculate_collab_score(user_item_matrix)
    print(f"Relevant Score: {cos_sim.max().max():.2f}, RMSE: {rmse:.2f}")

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for i, house_index in enumerate(sorted_indices[:15]):
    content_score = cos_sim[0][house_index]
    if region in collab_scores:
        collab_score = collab_scores[region]
        combined_score = (content_weight * content_score) + (collab_weight * collab_score)
    else:
        combined_score = content_score
    combined_scores[i+1] = {
        "House Index": house_index,
        "Content Score": content_score,
        "Combined Score": combined_score
    }

# Sort combined scores and print the top 15 houses
print("\nTop 15 Houses based on Hybrid Filtering:")
for i, data in combined_scores.items():
    house_index = data['House Index']
    house_category = region_houses.iloc[house_index]['attributes.category_name']
    house_subject = region_houses.iloc[house_index]['attributes.subject']
    house_body = region_houses.iloc[house_index]['attributes.body']
    house_region = region_houses.iloc[house_index]['attributes.region_name']
    house_property_type = region_houses.iloc[house_index]['attributes.property_type_name']
    print(f"{i}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Content Score: {data['Content Score']:.2f}, Combined Score: {data['Combined Score']:.2f})")
# Out:
# Enter keywords and region (e.g., 'apartment,johor'):  flat,johor
# C:\Users\User\AppData\Local\Temp\ipykernel_11384\2123671082.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   region_houses['text'] = region_houses[['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']].fillna('').apply(lambda x: ' '.join(x), axis=1)
# Top 15 Houses based on Hybrid Filtering:
# 1. Category: apartment condominium, Subject: flat austin perdana, Body: high floor, Region: johor, Property Type: flat (Content Score: 0.68, Combined Score: 0.68)
# 2. Category: apartment condominium, Subject: tun aminah low cost flat sale, Body: sale tun aminah flat blok flat low cost flat third floor bedroom bathroom 494sqft freehold basic renovated selling price rm150k, Region: johor, Property Type: flat (Content Score: 0.65, Combined Score: 0.65)
# 3. Category: apartment condominium, Subject: skudai flat taman ungku tun aminah sale, Body: sale flat tun aminah low cost flat highest floor build sqft bedroom bathroom freehold non bumi selling price rm135k nego, Region: johor, Property Type: flat (Content Score: 0.61, Combined Score: 0.61)
# 4. Category: apartment condominium, Subject: flat sale, Body: sale flat camar perling  level  r b  sq ft  non-bumi  freehold  balcony  fully tile  table top  cabinet harga rm160k , Region: johor, Property Type: flat (Content Score: 0.60, Combined Score: 0.60)
# 5. Category: apartment condominium, Subject: taman molek flat, Body: sale medium cost flat corner taman molek medium cost flat corner sq ft freehold non bumi lot level bedroom bathroom fully renovated selling price rm185,000 interested please contact alicia ren, Region: johor, Property Type: flat (Content Score: 0.57, Combined Score: 0.57)
# 6. Category: apartment condominium, Subject: seri alam tasek flat cheapest unit flat sale, Body: sell flat tasek seri alam blok l-05-xx low cost flat -2 room bathroom -656sqft -freehold -balcony -non bumi lot -high floor level selling price rm108k bank value rm130k full loan          contact  andrew teo 012-5249501                  , Region: johor, Property Type: flat (Content Score: 0.56, Combined Score: 0.56)
# 7. Category: apartment condominium, Subject: taman perling low cost flat bukit indah second link full loan, Body: sale  perling  flat   jalan camar taman perling -low cost flat level -built sq ft -2 bedroom bathroom -freehold -non bumi lot -renovated unit selling price rm198k  alvin ng, Region: johor, Property Type: flat (Content Score: 0.55, Combined Score: 0.55)
# 8. Category: apartment condominium, Subject: medium cost flat jasa mutiara rini, Body: sale flat jasa mutiara rini medium cost flat built sqft level bedroom bathroom non bumi lot leasehold original condition selling price rm150k please contact alicia ren, Region: johor, Property Type: flat (Content Score: 0.54, Combined Score: 0.54)
# 9. Category: apartment condominium, Subject: seri alam tasek flat low cost full loan masai, Body: sell flat tasek seri alam blok l-05-xx low cost flat -2 room bathroom -656sqft -freehold -balcony -non bumi lot -selling price rm108k alan, Region: johor, Property Type: flat (Content Score: 0.53, Combined Score: 0.53)
# 10. Category: apartment condominium, Subject: tun aminah flat skudai, Body: sale tun aminah low cost flat blk level bedroom bathroom sqft freehold fully renovation seller price rm158k, Region: johor, Property Type: flat (Content Score: 0.52, Combined Score: 0.52)
# 11. Category: apartment condominium, Subject: kulai indahpura temenggong flat level low floor freehold bedroom, Body:  tenggong flat  sale flat temenggong bandar indahpura.kulai tingkat sqft chinese owner freehold 2bedroom 1bathroom sellingrm128k, Region: johor, Property Type: flat (Content Score: 0.51, Combined Score: 0.51)
# 12. Category: apartment condominium, Subject: tun aminah flat|skudai|kulai|pulai|gaji 3.8k dpt|kempas|100 loan|, Body: taman ungku tun aminah flat block taman ungku tun aminah tuta flat low cost flat 4th floor bedroom bathroom sqft freehold intermediate lot non bumi lot selling price rm108k jp tiong www.wasap.my/+60177458657, Region: johor, Property Type: flat (Content Score: 0.51, Combined Score: 0.51)
# 13. Category: apartment condominium, Subject: flat tun aminah flat skudai full loan sale jual, Body: property address flat tun aminah area tun aminah bedroom bathroom size leasehold freehold freehold bumi non bumi non bumi maintenance fee parking selling price rm105k jack chai royce property, Region: johor, Property Type: flat (Content Score: 0.51, Combined Score: 0.51)
# 14. Category: apartment condominium, Subject: flat tasek seri alam sale, Body: flat tasek seri alam blok l-05-xx flat ko rendah bilik bilik air saiz 656sqft freehold ada balcony non bumi lot harga rm108k hubungi azzam ren, Region: johor, Property Type: flat (Content Score: 0.51, Combined Score: 0.51)
# 15. Category: apartment condominium, Subject: flat harmoni kangkar pulai level limited unit sale, Body: sale rm 125k address block xx level kangkar pulai jalan harmoni flat type low cost flat unit type tenure leasehold non bumi bedroom bathroom built 500sqft renovation kitchen table top fully tile furnishing yvonne, Region: johor, Property Type: flat (Content Score: 0.50, Combined Score: 0.50)

# %%
# Load house data
house_data_path = r"C:\Users\User\Desktop\dataset\mudah_all_dataV2.csv"
house_data = pd.read_csv(house_data_path)

# User input for keywords and region
keywords_region = input("Enter keywords and region (e.g., 'apartment,johor'): ")
keywords, region = keywords_region.split(',')

# Filter houses from the specified region
region_filter = house_data['attributes.region_name'].str.lower() == region.strip().lower()
region_houses = house_data[region_filter]

# Concatenate selected columns into a single text column
region_houses['text'] = region_houses[['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']].fillna('').apply(lambda x: ' '.join(x), axis=1)

# Initialize and fit TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(region_houses['text'])

# Transform user input into a document vector
user_document = ' '.join(keywords.split())
user_vector = tfidf_vectorizer.transform([user_document])

# Calculate cosine similarity between user input and house data
cos_sim = cosine_similarity(user_vector, tfidf_matrix)

# Get indices of houses sorted by relevance
sorted_indices = cos_sim.argsort()[0][::-1]

# Load user ratings data
ratings_data_path = r"C:\Users\User\Desktop\response.csv"
ratings_data = pd.read_csv(ratings_data_path)

# Function to calculate collaborative filtering scores and RMSE
def calculate_collab_score(user_item_matrix):
    user_item_matrix.fillna(0, inplace=True)
    X = user_item_matrix.values
    model = NMF(n_components=20, init='random', random_state=20)
    W = model.fit_transform(X)
    X_reconstructed = np.dot(W, model.components_)
    rmse = np.sqrt(np.mean((X - X_reconstructed)**2))
    collab_score = 1 / (1 + rmse)
    return collab_score, rmse

# Calculate collaborative filtering scores and RMSE for the specified region
collab_scores = {}
metrics = [f'{metric}.{region.lower()}' for metric in ['traffic', 'air_pollution', 'sound_pollution', 'crime_rate', 'overall_rating']]
if all(metric in ratings_data.columns for metric in metrics):
    user_item_matrix = pd.pivot_table(ratings_data, values=metrics, index='Username')
    collab_scores[region], rmse = calculate_collab_score(user_item_matrix)
    print(f"Relevant Score: {cos_sim.max().max():.2f}, RMSE: {rmse:.2f}")

# Weight for each method (content-based and collaborative)
content_weight = 0.7
collab_weight = 0.3

# Combine scores for each house
combined_scores = {}
for i, house_index in enumerate(sorted_indices[:15]):
    content_score = cos_sim[0][house_index]
    if region in collab_scores:
        collab_score = collab_scores[region]
        combined_score = (content_weight * content_score) + (collab_weight * collab_score)
    else:
        combined_score = content_score
    combined_scores[i+1] = {
        "House Index": house_index,
        "Content Score": content_score,
        "Combined Score": combined_score
    }

# Sort combined scores and print the top 15 houses
print("\nTop 15 Houses based on Hybrid Filtering:")
for i, data in combined_scores.items():
    house_index = data['House Index']
    house_category = region_houses.iloc[house_index]['attributes.category_name']
    house_subject = region_houses.iloc[house_index]['attributes.subject']
    house_body = region_houses.iloc[house_index]['attributes.body']
    house_region = region_houses.iloc[house_index]['attributes.region_name']
    house_property_type = region_houses.iloc[house_index]['attributes.property_type_name']
    print(f"{i}. Category: {house_category}, Subject: {house_subject}, Body: {house_body}, Region: {house_region}, Property Type: {house_property_type} (Content Score: {data['Content Score']:.2f}, Combined Score: {data['Combined Score']:.2f})")
# Out:
# Enter keywords and region (e.g., 'apartment,johor'):  bungalow,negeri sembilan
# C:\Users\User\AppData\Local\Temp\ipykernel_11384\1616230.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   region_houses['text'] = region_houses[['attributes.category_name', 'attributes.subject', 'attributes.body', 'attributes.region_name', 'attributes.property_type_name']].fillna('').apply(lambda x: ' '.join(x), axis=1)
# Top 15 Houses based on Hybrid Filtering:
# 1. Category: house, Subject: 1.5 storey bungalow seremban south taman senawang perdana seremban, Body: direct owner, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.53, Combined Score: 0.53)
# 2. Category: house, Subject: bungalow lavender height, Body: sq.ft| http //www.wasap.my/60182222293, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.48, Combined Score: 0.48)
# 3. Category: house, Subject: bungalow house sale seremban rasah, Body: bungalow sale seremban rasah storey bungalow big land space freehold land size x 7,760 sqft room bathroom extra land back side renovated price rm 730k detail kindly contact eric teh 016-360, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.44, Combined Score: 0.44)
# 4. Category: land, Subject: bungalow land rasah kemayan seremban2, Body: bungalow land sale size sq meter, Region: negeri sembilan, Property Type: residential (Content Score: 0.44, Combined Score: 0.44)
# 5. Category: house, Subject: port dickson bungalow house sale, Body: wts vintage bungalow port dickson good condition freehold 4r3b lot size 9,103 sqft interested please contact viewing, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.42, Combined Score: 0.42)
# 6. Category: house, Subject: market |4room 50x80 1-storey bungalow mahkota hill lenggeng, Body: sale bilik tidur storey bungalow mahkota hill seksyen bandar tasik senangin lenggeng basic unit good condition property detail -- -- -- -- -- -- -- -- -- -- -- storey bungalow freehold bumi lot land area 4,000 sqft build 1,500 sqft approx bedroom bathroom basic unit vacant asking price rm450,000 nett, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.41, Combined Score: 0.41)
# 7. Category: house, Subject: rumah cantik bungalow mahkota hill lenggeng, Body: sale room bungalow mahkota hill seksyen bandar tasik senangin lenggeng -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- asking price rm 450,000 nett -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- property detail -- -- -- -- -- -- -- -- -- -- -- storey bungalow freehold bumi lot land area 4,000 sqft build 1,500 sqft approx bedroom bathroom basic unit vacant kindly contact detail call zhariff iqi realty ren36842, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.40, Combined Score: 0.40)
# 8. Category: house, Subject: bungalow w big land seremban rasah, Body: double storey bungalow taman guru rasah rm1.1mil freehold non bumi lot 6+1 room bathroom land size 12000sf renovated furnished main gate a/c kitchen cabinet wardrobe min plus tol min seremban, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.38, Combined Score: 0.38)
# 9. Category: house, Subject: nice double storey bungalow rasah kemayan sale, Body: nice double storey bungalow rasah kemayan sale freehold non bumi sqft bed bath renovated house selling 880k please contact charles liew, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.37, Combined Score: 0.37)
# 10. Category: house, Subject: nice double storey bungalow batu port dickson sale, Body: nice double storey bungalow batu port dickson sale freehold non bumi land size sqft bed bath renovated house private swimming pool selling 1.1m please contact charles liew, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.37, Combined Score: 0.37)
# 11. Category: house, Subject: double storey bungalow rasah kemayan sale, Body: double storey bungalow rasah kemayan sale freehold non bumi land size sqft 5+1 bed bath partial renovated asking 780k nego please contact charles liew 012-2684787, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.36, Combined Score: 0.36)
# 12. Category: house, Subject: bungalow tanah besar taman rashidah utama senawang, Body: storey bungalow sale taman rashidah utama jalan paroi senawang seremban negeri sembilan storey bungalow room bath freehold rezab melayu luas tanah mps/5403 sqf asking price rm650,000 www.wasap.my/+60193231429, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.36, Combined Score: 0.36)
# 13. Category: house, Subject: seremban bandar sri sendayan bungalow, Body: non bumi lot bungalow house location bandar sri sendayan near seremban fully renovated .. wide kitchen area extend swimming pool plaster ceiling tile renovation cost 200k call house visit adjust full loan muhamad, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.35, Combined Score: 0.35)
# 14. Category: house, Subject: nice single storey bungalow sri pulai sale, Body: nice single storey bungalow sri pulai sale freehold non bumi 50x80 bed bath kitchen cabinet plaster ceiling floor tile selling 520k please contact charles liew, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.35, Combined Score: 0.35)
# 15. Category: house, Subject: mv 1.5 storey bungalow pool rasah kemayan seremban, Body: 1.5 storey bungalow pool rasah kemayan seremban bungalow 1.5 storey intermediate nonbumi freehold land size 5400sqft built size 4,000sqft approx bedroom bathroom renovated second living hall dry kitchen lounge area swimming pool asking price rm 900,000 interested let 's viewing appreciate www.wasap.my/+60199437090/rasahpool, Region: negeri sembilan, Property Type: bungalow house (Content Score: 0.35, Combined Score: 0.35)
